# %% [markdown]
# # Описание данных
#
#
# 1. marketing_dealer - список дилеров;
#
# 2. marketing_dealerprice - результат работы парсера площадок дилеров:
#       * product_key - уникальный номер позиции;
#       * price - цена;
#       * product_url - адрес страницы, откуда собраны данные;
#       * product_name - заголовок продаваемого товара;
#       * date - дата получения информации;
#       * dealer_id - идентификатор дилера (внешний ключ к marketing_dealer)
#
# 3. marketing_product - список товаров, которые производит и распространяет заказчик:
#       * article - артикул товара;
#       * ean_13 - код товара (см. EAN 13)
#       * name - название товара;
#       * cost - стоимость;
#       * recommended_price - рекомендованная цена;
#       * category_id - категория товара;
#       * ozon_name - названиет товара на Озоне;
#       * name_1c - название товара в 1C;
#       * wb_name - название товара на Wildberries;
#       * ozon_article - описание для Озон;
#       * wb_article - артикул для Wildberries;
#       * ym_article - артикул для Яндекс.Маркета;
#
# 4. marketing_productdealerkey - таблица матчинга товаров заказчика и товаров дилеров
#       * key - внешний ключ к marketing_dealerprice
#       * product_id - внешний ключ к marketing_product
#       * dealer_id - внешний ключ к marketing_dealer

# %%
import pandas as pd
import os.path
import re
import nltk

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Функция для добавления пропущенных пробелов в наименованиях.
def add_spaces(text):
    spaced_text = re.sub(r'(?<=[a-zA-Z])(?=[а-яА-ЯёЁ])|(?<=[а-яА-ЯёЁ])(?=[a-zA-Z])', ' ', text)
    spaced_text = re.sub(r'(\S)\*(\S)', r'\1 * \2', spaced_text)
    spaced_text = re.sub(r'(\d+)([а-яА-ЯёЁa-zA-Z]+)', r'\1 \2', spaced_text)
    return spaced_text


# Функция для извлечения концентрации, объема, единицы измерения и фасовки из наименования товара в отдельные столбцы.
def extract_info(data):
    pattern_volume = r'\s*(\d+(?:[.,]\d+)?)\s*([мк]?[лг]|лит[р]?[ы]?|к[г]?[р]?[ам]?[ы]?)\s*'
    pattern_concentration = r'\s*(\d+:\d+)\s*'
    pattern_quantity = r'\s*(\d+)\s*(?:шт(?:ук[и]?|\.)?|ШТ|шт)\s*'

    data['volume'] = data['name'].str.extract(pattern_volume, expand=True)[0]
    data['units_of_meas'] = data['name'].str.extract(pattern_volume, expand=True)[1]
    data['concent'] = data['name'].str.extract(pattern_concentration, expand=False)
    data['units'] = data['name'].str.extract(pattern_quantity, expand=False)
    
    data['units'].fillna('1', inplace=True)
    data['concent'].fillna('1:1', inplace=True)
    data['volume'].fillna('1', inplace=True)
    data['units_of_meas'].fillna('шт', inplace=True)
    
    # Добавляем ваш фрагмент кода для удаления лишних пробелов между буквой и словом
    data['name'] = data['name'].str.replace(r'(\w)\s+(?=\w)', r'\1')

    return data


# Функция для извлечения первых 3-4 слов из названия товара
def extract_keywords(name):
    words = name.split()[:4]
    return ' '.join(words)


# Функция очистки,  токенизации, лемматизации и удаление стоп-слов.
def preprocess_text(text):
    # Очистка текста
    cleaned_text = re.sub(r"[^a-zA-Zа-яА-ЯёЁ ]", ' ', text)
    
    # Токенизация
    tokens = word_tokenize(cleaned_text.lower())
    
    # Лемматизация
    lemmatizer = WordNetLemmatizer()
    lemmas = [lemmatizer.lemmatize(token) for token in tokens]
    
    # Удаление стоп-слов
    stop_words = set(stopwords.words('russian') + stopwords.words('english'))
    filtered_words = [lemma for lemma in lemmas if lemma not in stop_words]
    
    # Возвращение предобработанного текста
    return ' '.join(filtered_words)

# %%
data_dir = 'C:/Users/tra88/Downloads/Prosept'
try:
    df_a = os.path.join(data_dir, 'marketing_dealer.csv')
    dealers_id = pd.read_csv(df_a, sep=';')
    
    df_b = os.path.join(data_dir, 'marketing_dealerprice.csv')
    data_dealers = pd.read_csv(df_b, sep=';', parse_dates=['date'])
    
    df_c = os.path.join(data_dir, 'marketing_product.csv')
    data_products = pd.read_csv(df_c, sep=';', index_col='Unnamed: 0')
    
    df_d = os.path.join(data_dir, 'marketing_productdealerkey.csv')
    data_key = pd.read_csv(df_d, sep=';')
    
except:
    dealers_id = pd.read_csv('marketing_dealer.csv', sep=';')
    data_dealers = pd.read_csv('marketing_dealerprice.csv', sep=';')
    data_products = pd.read_csv('marketing_product.csv', sep=';', index_col='Unnamed: 0')
    data_key = pd.read_csv('marketing_productdealerkey.csv', sep=';')

# %%
dealers_id
# Out:
#     id                      name
# 0    1              Moi_vibor_WB
# 1    2                     Akson
# 2    3                     Bafus
# 3    5                 Castorama
# 4    6                  Cubatora
# 5    7                     Komus
# 6    9                 Megastroy
# 7   10               OnlineTrade
# 8   11                 Petrovich
# 9   12                     sdvor
# 10  13                  simaLand
# 11  14                    VegosM
# 12  15            Vse_instrumeni
# 13  16                     Vimos
# 14   4                 Baucenter
# 15   8              Leroy_Merlin
# 16  18  Мasterstroy_spb_OZON\r\n
# 17  17           Unicleaner_OZON

# %%
dealers_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      18 non-null     int64
#  1   name    18 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 420.0+ bytes

# %% [markdown]
# **Вывод о dealers_id:**
#
#
# В датафрейме dealers_id содержит 18 строк и 2 столбца. Пропуски и дубликаты в датафрейме отстутствуют.

# %%
data_dealers.sample(10)
# Out:
#           id product_key   price  \
# 2334    2333   100121701  1354.0
# 14457  14522   700000620   729.0
# 3623    3745      856995  1798.0
# 2692    2670     1656315   308.0
# 10100  10242   100121836   436.0
# 12910  13009   100121788  6581.0
# 11569  11710   100121705  5107.0
# 17622  17775      344052   195.0
# 12462  12564    44231934   823.0
# 13269  13335     1302289   469.0
#
#                                              product_url  \
# 2334                     https://www.bafus.ru/100121701/
# 14457  https://baucenter.ru/sredstva-ot-pleseni-gribk...
# 3623   https://akson.ru//p/shpatlevka_dlya_plit_osb_p...
# 2692   https://www.onlinetrade.ru/catalogue/sredstva_...
# 10100                    https://www.bafus.ru/100121836/
# 12910                    https://www.bafus.ru/100121788/
# 11569                    https://www.bafus.ru/100121705/
# 17622        https://kazan.megastroy.com/products/344052
# 12462  https://www.wildberries.ru/catalog/44231934/de...
# 13269  https://www.onlinetrade.ru/catalogue/sredstva_...
#
#                                             product_name       date  dealer_id
# 2334   Просепт Professional Multipower Bright средств... 2023-07-12          3
# 14457  Средство для защиты от плесени PROSEPT FUNGI S... 2023-07-25          4
# 3623   Шпаклевка для OSB-плит акриловая PROSEPT Propl... 2023-07-13          2
# 2692   Удалитель плесени PROSEPT FUNGI CLEAN, 500 мл,... 2023-07-12         10
# 10100  Просепт Professional Crystal Black Active жидк... 2023-07-19          3
# 12910  Просепт Professional Duty Mud низкопенный конц... 2023-07-24          3
# 11569  Просепт Professional Polish 250 полимерное пок... 2023-07-21          3
# 17622  Средство д/мытья полов PROSEPT Multipower Floo... 2023-07-28          9
# 12462                                   Концентрат ULTRA 2023-07-21          1
# 13269  Средство для удаления плесени PROSEPT Bath Fun... 2023-07-24         10

# %%
data_dealers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20416 entries, 0 to 20415
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20416 non-null  int64
#  1   product_key   20416 non-null  object
#  2   price         20416 non-null  float64
#  3   product_url   20182 non-null  object
#  4   product_name  20416 non-null  object
#  5   date          20416 non-null  datetime64[ns]
#  6   dealer_id     20416 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 1.1+ MB

# %%
df = data_dealers.query('product_url.isna()')
df['dealer_id'].unique()
# Out:
# array([7], dtype=int64)

# %% [markdown]
# Видно, что имеются пропуски. Посмотрим процент этих пропусков.

# %%
(data_dealers.isna().sum() / len(data_dealers)) * 100
# Out:
# id              0.00000
# product_key     0.00000
# price           0.00000
# product_url     1.14616
# product_name    0.00000
# date            0.00000
# dealer_id       0.00000
# dtype: float64

# %%
print('Количество явных дубликатов: ', data_dealers.duplicated().sum())
# Out:
# Количество явных дубликатов:  0

# %% [markdown]
# Посмотрим количество уникальных наименований товаров

# %%
print('Количество уникальных наименований столбца product_name: ', len(data_dealers['product_name'].unique()))
# Out:
# Количество уникальных наименований столбца product_name:  1953

# %% [markdown]
# **Вывод о data_dealers:**
#
# 1. Датафрейм содержит 7 столбцов и 20416 строк.
# 2. Дубликаты не обнаружены.
# 3. Имеются пропуски в столбце product_url (1,2%)

# %% [markdown]
# Изучим информацию в датафрейме data_products.

# %%
data_products.sample(10)
# Out:
#       id   article        ean_13  \
# 114  191  D1 02500  4.610093e+12
# 196  391     019-1  4.680008e+12
# 270   28     231-1  4.680008e+12
# 495   52   113-075  4.680008e+12
# 450   64     189-5  4.680008e+12
# 447    9     107-5  4.680008e+12
# 421   38     246-1  4.680008e+12
# 259  290     025-5  4.680008e+12
# 222  467   М015-12  4.610093e+12
# 339  380     046-3  4.680008e+12
#
#                                                   name     cost  \
# 114  Дезинфицирующее средство ПРОФ ДЗ "PROF DZ" гот...   156.00
# 196  Удалитель плесени FUNGI CLEAN концентрат 1:1 /...   212.00
# 270  Концентрат эконом-класса для мытья половMultip...    88.79
# 495  Средство усиленного действия для удаления ржав...    75.00
# 450  Средство для чистки акриловых поверхностейBath...   456.61
# 447  Универсальное моющее средство с дезинфицирующи...   594.00
# 421  Концентрат для мытья половMULTIPOWER с аромато...   101.94
# 259  Антисептик против грибка и плесени АНТИПЛЕСЕНЬ...   251.00
# 222  Герметик акриловый цвет орех, ф/п 600мл (12 шт...  3686.40
# 339     Грунт АКВАИЗОЛ, розовый, концентрат  1:9 / 3 л   658.00
#
#      recommended_price  category_id  \
# 114               0.00         21.0
# 196             506.00         35.0
# 270             208.00         50.0
# 495             176.00         52.0
# 450            1067.00         46.0
# 447            1388.00         56.0
# 421             239.00         50.0
# 259             598.00         20.0
# 222            7716.96         25.0
# 339            1485.00         26.0
#
#                                              ozon_name  \
# 114  Дезинфицирующее средство PROSEPT PROF DZ, 500 мл.
# 196  Удалитель плесени PROSEPT FUNGI CLEAN, концент...
# 270  Средство для мытья полов всех типов PROSEPT Mu...
# 495  Усиленное средство для удаления ржавчины и мин...
# 450  Средство для чистки акриловых ванн и душевых к...
# 447  Моющее средство с дезинфицирующим эффектом PRO...
# 421  Средство для мытья полов PROSEPT Multipower ci...
# 259  Антисептик универсальный против грибка и плесе...
# 222  Герметик акриловый для швов для деревянных дом...
# 339      Грунт влагоизолирующий PROSEPT Акваизол, 3 л.
#
#                                                name_1c  \
# 114  Дезинфицирующее средство PROSEPT PROF DZ, 500 мл.
# 196  Удалитель плесени PROSEPT FUNGI CLEAN, концент...
# 270  Средство для мытья полов всех типов PROSEPT Mu...
# 495  Усиленное средство для удаления ржавчины и мин...
# 450  Средство для чистки акриловых ванн и душевых к...
# 447  Моющее средство с дезинфицирующим эффектом PRO...
# 421  Средство для мытья полов PROSEPT Multipower ci...
# 259  Антисептик универсальный против грибка и плесе...
# 222  Герметик акриловый для швов для деревянных дом...
# 339      Грунт влагоизолирующий PROSEPT Акваизол, 3 л.
#
#                                                wb_name  ozon_article  \
# 114  Дезинфицирующее средство PROSEPT PROF DZ, 500 мл.           NaN
# 196  Удалитель плесени PROSEPT FUNGI CLEAN, концент...   189522721.0
# 270  Средство для мытья полов всех типов PROSEPT Mu...   451081249.0
# 495  Усиленное средство для удаления ржавчины и мин...   413264558.0
# 450  Средство для чистки акриловых ванн и душевых к...   451565754.0
# 447  Моющее средство с дезинфицирующим эффектом PRO...   449936777.0
# 421  Средство для мытья полов PROSEPT Multipower ci...   417953521.0
# 259  Антисептик универсальный против грибка и плесе...   189522744.0
# 222  Герметик акриловый для швов для деревянных дом...   189522825.0
# 339      Грунт влагоизолирующий PROSEPT Акваизол, 3 л.   453014587.0
#
#       wb_article ym_article wb_article_td
# 114  150119532.0   D1-02500           NaN
# 196  149974141.0      019-1           NaN
# 270  151231991.0      231-1           NaN
# 495  149811041.0    113-075           NaN
# 450  149811057.0      189-5           NaN
# 447  149811021.0      107-5           NaN
# 421  151231986.0      246-1           NaN
# 259  150033472.0      025-5           NaN
# 222  161240419.0    M015-12           NaN
# 339  149699629.0      046-3           NaN

# %%
data_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 496 entries, 0 to 495
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 496 non-null    int64
#  1   article            496 non-null    object
#  2   ean_13             464 non-null    float64
#  3   name               494 non-null    object
#  4   cost               491 non-null    float64
#  5   recommended_price  491 non-null    float64
#  6   category_id        447 non-null    float64
#  7   ozon_name          458 non-null    object
#  8   name_1c            485 non-null    object
#  9   wb_name            455 non-null    object
#  10  ozon_article       365 non-null    float64
#  11  wb_article         340 non-null    float64
#  12  ym_article         337 non-null    object
#  13  wb_article_td      32 non-null     object
# dtypes: float64(6), int64(1), object(7)
# memory usage: 58.1+ KB

# %% [markdown]
# Видно, что в столбцах имеются пропуски посмотрим, какое процент этих пропусков.

# %%
(data_products.isna().sum() / len(data_products)) *100
# Out:
# id                    0.000000
# article               0.000000
# ean_13                6.451613
# name                  0.403226
# cost                  1.008065
# recommended_price     1.008065
# category_id           9.879032
# ozon_name             7.661290
# name_1c               2.217742
# wb_name               8.266129
# ozon_article         26.411290
# wb_article           31.451613
# ym_article           32.056452
# wb_article_td        93.548387
# dtype: float64

# %% [markdown]
# Есть большое количество пропусков в столбце wb_article_td (почти 94%). Также достаточно большой обьем пропусков содержится в столбцах с артикулами (ozon_article, wb_article, ym_article). В этих столбцах обьем процент пропусков находится в диапазоне от 26,4% до 32,1%.
#
#  Столбец wb_article_td имеет смысл удалить, поскольку восстановить такой обьем пропусков практически невозможно. Поэтому лучше убрать столбцы ean_13, wb_article, ozon_article, ym_article, wb_article_td.

# %%
data_products = data_products.drop(['wb_article_td', 'ean_13', 'ozon_article', 'wb_article', 'ym_article'], axis=1)

# %%
data_products.query('recommended_price == 0.0')
# Out:
#       id   article                                               name    cost  \
# 45   187  D1 01050  Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый со...    44.0
# 59   189  D1 01001  Кожный антисептик ПРОФ ДЗ "PROF DZ"готовый сос...   240.0
# 113  190  D1 01005  Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый со...  1164.0
# 114  191  D1 02500  Дезинфицирующее средство ПРОФ ДЗ "PROF DZ" гот...   156.0
# 135  192  D1 02005  Дезинфицирующее средство ПРОФ ДЗ "PROF DZ" гот...  1164.0
# 145  188  D1 01100  Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый со...    56.0
#
#      recommended_price  category_id  \
# 45                 0.0         21.0
# 59                 0.0         21.0
# 113                0.0         21.0
# 114                0.0         21.0
# 135                0.0         21.0
# 145                0.0         21.0
#
#                                              ozon_name  \
# 45   Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый со...
# 59             Кожный антисептик PROSEPT PROF DZ, 1 л.
# 113            Кожный антисептик PROSEPT PROF DZ, 5 л.
# 114  Дезинфицирующее средство PROSEPT PROF DZ, 500 мл.
# 135  Дезинфицирующее средство ПРОФ ДЗ "PROF DZ" гот...
# 145  Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый со...
#
#                                                name_1c  \
# 45   Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый со...
# 59             Кожный антисептик PROSEPT PROF DZ, 1 л.
# 113            Кожный антисептик PROSEPT PROF DZ, 5 л.
# 114  Дезинфицирующее средство PROSEPT PROF DZ, 500 мл.
# 135  Дезинфицирующее средство ПРОФ ДЗ "PROF DZ" гот...
# 145  Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый со...
#
#                                                wb_name
# 45   Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый со...
# 59             Кожный антисептик PROSEPT PROF DZ, 1 л.
# 113            Кожный антисептик PROSEPT PROF DZ, 5 л.
# 114  Дезинфицирующее средство PROSEPT PROF DZ, 500 мл.
# 135  Дезинфицирующее средство ПРОФ ДЗ "PROF DZ" гот...
# 145  Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый со...

# %%
data_products.query('cost.isna() or recommended_price.isna()')
# Out:
#       id      article                                               name  \
# 4    502     0024-7 б               Герметик акриловой  цвет Белый, 7 кг
# 23   503     0024-7 о                                                NaN
# 35   504      w022-05                                                NaN
# 109  449  0024-06 м12      Герметик акриловый цвет Медовый 0,6 л (12 шт)
# 110  454  0024-06 о12  Герметик акриловый цвет Орех, ф/п 600мл (12 шт...
#
#      cost  recommended_price  category_id ozon_name  \
# 4     NaN                NaN          NaN       NaN
# 23    NaN                NaN          NaN       NaN
# 35    NaN                NaN          NaN       NaN
# 109   NaN                NaN         25.0       NaN
# 110   NaN                NaN         25.0       NaN
#
#                                                name_1c wb_name
# 4                                                  NaN     NaN
# 23                                                 NaN     NaN
# 35                                                 NaN     NaN
# 109      Герметик акриловый цвет Медовый 0,6 л (12 шт)     NaN
# 110  Герметик акриловый цвет сосна, ф/п 600мл (12 ш...     NaN

# %%
data_products.dropna(subset=['name'], inplace=True)

# %%
data_products.query('name_1c.isna()')
# Out:
#       id     article                                               name  \
# 4    502    0024-7 б               Герметик акриловой  цвет Белый, 7 кг
# 31   118      273-20  Средство усиленного действия для чистки коптил...
# 32   119      274-20  Средство низкопенное  для  очистки  алюминия и...
# 46   182    P1 11005  Cредство для рук гигиеническое с антибактериал...
# 47   181    P1 11800  Cредство для рук гигиеническое с антибактериал...
# 60   186    P1 06005  Жидкое мыло с антибактериальным компонентом дл...
# 98   436    Р1 09005
# 102  433  D1 01050-3   Кожный антисептик PROF DZ готовый состав / 0,1 л
# 115  456      М007-2  Антисептик для рук PROSEPT PROF DZ, 2 штуки*10...
#
#        cost  recommended_price  category_id  \
# 4       NaN                NaN          NaN
# 31   3730.0             8712.0          NaN
# 32   2818.0             6581.0          NaN
# 46    565.0             1319.0          NaN
# 47    155.0              361.0          NaN
# 60    492.0             1067.0          NaN
# 98    500.0              600.0          NaN
# 102   112.8              226.0          NaN
# 115   112.0              224.0         21.0
#
#                                              ozon_name name_1c wb_name
# 4                                                  NaN     NaN     NaN
# 31                                                 NaN     NaN     NaN
# 32                                                 NaN     NaN     NaN
# 46                                                 NaN     NaN     NaN
# 47                                                 NaN     NaN     NaN
# 60                                                 NaN     NaN     NaN
# 98                                                 NaN     NaN     NaN
# 102                                                NaN     NaN     NaN
# 115  Антисептик для рук PROSEPT PROF DZ, 2 штуки*10...     NaN     NaN

# %%
empty_name_rows = data_products[data_products['name'].str.contains(r'^\s*$')]
empty_name_rows
# Out:
#      id   article name   cost  recommended_price  category_id ozon_name  \
# 98  436  Р1 09005       500.0              600.0          NaN       NaN
#
#    name_1c wb_name
# 98     NaN     NaN

# %%
data_products.drop(index=empty_name_rows.index, inplace=True)

# %%
data_products['name'].unique()
# Out:
# array(['Антисептик невымываемыйPROSEPT ULTRAконцентрат 1:10  / 1 л',
#        'Антигололед - 32 PROSEPTготовый состав / 12 кг',
#        'Герметик акриловый цвет сосна, ф/п 600мл',
#        'Кондиционер для белья с ароматом  королевского ИрисаCrystal Rinserконцентрат / 2 л ',
#        'Герметик акриловой  цвет Белый, 7 кг',
#        'Грунт БЕТОНКОНТАКТготовый состав / 6 кг',
#        'Грунт БЕТОНКОНТАКТготовый состав / 12 кг',
#        'Средство для удаления технических масел, смазочных материалов и нефтепродуктовDuty Oil концентрат 1:20-1:150 /  5 л',
#        'Антисептик универсальный суперсильный',
#        'Средство для мытья светлых полов с отбеливающим эффектомMultipower Whiteконцентрат 1:20-1:200 / 1 л',
#        'Отбеливатель для древесины PROSEPT 50концентрат 1:1 / 5 л',
#        'Антисептик лессирующий BiO LASUR / тик / 9 л',
#        'Антисептик лессирующий BiO LASUR / махагон / 0,9 л',
#        'Антисептик лессирующий BiO LASUR / лиственница / 0,9 л',
#        'Антисептик лессирующий BiO LASUR / тик / 0,9 л',
#        'Средство для мытья полов и стенMultipower "Полевые цветы"концентрат  1:10 – 1:120 / 0,8 л',
#        'Антисептик лессирующий BiO LASUR / тик / 2,7 л',
#        'Антисептик лессирующий BiO LASUR / махагон / 9 л',
#        'Антисептик лессирующий BiO LASUR / дуб / 2,7 л',
#        'Антисептик лессирующий BiO LASUR / палисандр / 0,9 л',
#        'Антисептик лессирующий BiO LASUR / палисандр / 2,7 л',
#        'Антисептик лессирующий BiO LASUR / палисандр / 9 л',
#        'Антисептик лессирующий BiO LASUR / орех / 9 л',
#        'Средство для мытья полов и стен Multipower "После дождя"концентрат 1:10 – 1:120 / 0,8 л',
#        'Гель для мытья  посуды вручную. Без запахаCookyконцентрированное средство / 0,5 л ',
#        'Средство усиленного действия для удаления ржавчины и минеральных отложенийBath Acid +  с ароматом цитрусаконцентрат 1:200-1:500 / 0,75 л',
#        'Герметик акриловый  цвет медовый ф/п 600 мл. (12 штук )',
#        'Cредство для чистки коптильных камерCooky Smokeконцентрат 1:10-1:100 / 20 л',
#        'Гель эконом-класса для мытья посуды вручную. С ароматом лимонаCooky Gel Lemon концентрированное средство / 5 л ',
#        'Антибактериальное мылоDiona Antibacготовое средство / 5 л ПЭТ',
#        'Средство усиленного действия для чистки коптильных камерDuty Fogконцентрат / 20 л',
#        'Средство низкопенное  для  очистки  алюминия и сплавов на его основеDuty Mud  концентрат / 20 л',
#        'Кондиционер для белья с ароматом лепестков СакурыCrystal Rinserконцентрат / 2 л ',
#        'Набор для посудомоечной посуды PROSEPT, 3 средства',
#        'Стиральный порошок для белых тканейCrystal White / 5 кг ПЭТ',
#        'Набор для стирки PROSEPT, 6 средств для всех типов тканей',
#        'Набор Удалитель мха, концентрат 1 л, 2 шт',
#        'Набор для посудомоечной посуды PROSEPT, 2 средства (гель и ополаскиватель)',
#        'Герметик акриловый цвет белый, ф/п 600 мл.',
#        'Огнебиозащита ОГНЕБИО PROF 2 группа бесцветный готовый состав / 10 л',
#        'Набор для посудомоечной посуды PROSEPT, 2 средства (ополаскиватель и соль)',
#        'Набор "Антиплесень" PROSEPT (удалитель плесени и защита от плесени)',
#        'жидкое гель-мыло эконом-класса. C ароматом яблокаDiona Apple Eготовое средство / 5 л ПЭТ',
#        'Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый состав / 0,05 л',
#        'Cредство для рук гигиеническое с антибактериальным эффектом PROSEPT готовый состав / 5 л',
#        'Cредство для рук гигиеническое с антибактериальным эффектом PROSEPT готовый состав / 0,8 л',
#        'Средство для мытья полов PROSEPT Multipower "Вершины Тибета", 2 штуки*0.8 л.',
#        'Пенное мыло для дозаторов. Без красителей и ароматизаторовDiona Flowerконцентрат / 5 л ',
#        'Набор для удаления загрязнений и наклеек PROSEPT, 2 средства (универсальный спрей для уборки и удалитель наклеек)',
#        'Набор Удалитель мха, готовый состав, 1 л, 2 шт',
#        'Средство для удаления граффити, маркера, краскиDuty Graffiti Maxготовый состав, аэрозоль / 2 л',
#        'Огнебиозащита ОГНЕБИО PROF 2 группа, красный готовый состав / 10 л',
#        'Чистящее средство, сода эффектCrystal Handготовый состав / 0,4 л',
#        'Антисептик невымываемыйPROSEPT ULTRAкоричневый концентрат 1:10 / 1 л',
#        'Антисептик для внутренних работPROSEPT SAUNAконцентрат 1:10 / 1 л',
#        'ПеногасительAntifoam концентрат до 1:300 / 1 л ',
#        'Набор Краска для OSB плит TopTex, 1 кг, 2 шт',
#        'Кожный антисептик ПРОФ ДЗ "PROF DZ"готовый состав / 1 л',
#        'Жидкое мыло с антибактериальным компонентом для диспенсеров с пенообразователемDiona AN FOAM / 5 л',
#        'Герметик акриловый цвет тик, ф/п 600мл',
#        'Средство для мытья полов PROSEPT Multipower "После дождя", 2 штуки*0.8 л.',
#        'Набор Очиститель фасадов SALT CLEANER, 1 л, 2 шт',
#        'Набор Universal Hard спрей, 0.5 л, 2 шт',
#        'Концентрат для мытья полов и стен Multipower "Цитрус" 0,8 л',
#        'Огнебиозащита ОГНЕБИО PROF 2 группа, красный готовый состав / 65 л',
#        'ОГНЕБИОЗАЩИТА I группа, красный готовый состав / 65 кг',
#        'Набор Duty Universal, 0.4 л, 2 шт',
#        'Набор Flox Prof спрей, 0.5 л, 2 шт',
#        'Набор Лак яхтный, глянцевый, 0.9 л, 2 шт',
#        'Набор Лак яхтный, полуматовый, 0.9 л, 2 шт',
#        'Антисептик лессирующий BiO LASUR / бук / 0,9 л',
#        'Антисептик лессирующий BiO LASUR / орех / 0,9 л',
#        'Антисептик лессирующий BiO LASUR / лиственница / 9 л',
#        'Антисептик лессирующий BiO LASUR / дуб / 0,9 л',
#        'Антисептик лессирующий BiO LASUR / дуб / 9 л',
#        'Герметик акриловый цвет Белый, 15 кг',
#        'Герметик акриловый цвет Белый, 3 кг',
#        'Антисептик лессирующий BiO LASUR / сосна / 2,7 л',
#        'Набор Шпатлевка для OSB Proplast 1,3 кг, 2 шт',
#        'Герметик акриловый цвет Орех 0,6 л',
#        'Герметик акриловый цвет Орех, 15 кг',
#        'Герметик акриловый цвет Орех, 3 кг',
#        'Герметик акриловый цвет Сосна, 3 кг',
#        'Набор Duty Leather, 0.4 л, 2 шт',
#        'Набор DUTY GRAFFITI, 0.4 л, 2 шт',
#        'Набор Шпатлевка-замазка трещин Plastix 1,4 кг, 2 шт',
#        'Герметик акриловый цвет белый ф/п 600 мл. (12 штук )',
#        'Антигололед - 32 PROSEPTготовый состав / 6 кг',
#        'Концентрат для мытья полов и стен  Multipower "Полевые цветы" 0,8 л 2ШТ',
#        'Концентрат для мытья полов и стен Multipower "Цитрус" 0,8 л 2 ШТ',
#        'Отбеливатель Prosept 50, концентрат, 1 л, 2 шт',
#        'Герметик акриловый цвет сосна, ф/п 600мл (12 штук )',
#        'Герметик акриловый цвет Медовый, 3 кг',
#        'Краска резиновая зеленый мох Ral 6005 / 12 кг',
#        'Антисептик ULTRA, концентрат, 1 л, 2 шт',
#        'Средство для мытья полов и стен Multipower  "Вершины Тибета"концентрат  1:10 – 1:120 / 0,8 л',
#        'Антисептик невымываемый PROSEPT ULTRAконцентрат  1:10  / 30 л',
#        'Средство для мытья посуды в посудомоечной машине. Для жесткой водыCooky Splash Hard концентрат 1:200-1:2000 / 20 л',
#        'Герметик акриловый цвет Сосна, 15 кг',
#        'Кожный антисептик PROF DZ готовый состав / 0,1 л',
#        'Антисептик лессирующий BiO LASUR / бук / 2,7 л',
#        'Антисептик трудновымываемый для наружных работ PROSEPT EXTERIORконцентрат 1:19 / 30 л',
#        'Герметик акриловый цвет Медовый 0,6 л',
#        'Антисептик универсальный для наружных и внутренних работPROSEPT UNIVERSALконцентрат 1:10 / 30 л',
#        'Антисептик невымываемый ХМ-11, ГОСТ / 20 л',
#        'ОГНЕБИОЗАЩИТА 2 группа, красный готовый состав / 65 кг',
#        'Герметик акриловый цвет Медовый 0,6 л (12 шт)',
#        'Герметик акриловый цвет Орех, ф/п 600мл (12 штук )',
#        'Антисептик лессирующий BiO LASUR / махагон / 2,7 л',
#        'Антисептик  ECO UNIVERSAL / 65 л',
#        'Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый состав / 5 л ',
#        'Дезинфицирующее средство ПРОФ ДЗ "PROF DZ" готовый состав / 0,5 л ',
#        'Антисептик для рук PROSEPT PROF DZ, 2 штуки*100 мл.',
#        'Моющее средство для пароконвектоматов с режимом автоматической очисткиCooky Degreaserконцентрат / 5 л',
#        'Жидкое гель-мыло с перламутром. Без цвета, без запахаDiona готовый состав / 5 л ПЭТ',
#        'Антисептик лессирующий BiO LASUR / сосна / 9 л',
#        'Краска резиновая черный Ral 9004 / 12 кг',
#        'Антисептик лессирующий BiO LASUR / орех / 2,7 л',
#        'Антисептик лессирующий BiO LASUR / лиственница / 2,7 л',
#        'Антисептик лессирующий BiO LASUR / бесцветный / 9 л',
#        'Антисептик лессирующий BiO LASUR / белый люкс / 9 л',
#        'Отбеливатель для древесиныPROSEPT 50концентрат 1:1 / 30 л',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, красный готовый состав / 30 л',
#        'Огнебиозащита   ОГНЕБИО PROF l, 1 группа, бесцветный готовый состав / 65 л',
#        'Огнебиозащита ОГНЕБИО PROF I, 1 группа, бесцветный готовый состав / 5 л',
#        'Антисептик ULTRA коричневый, концентрат, 1 л, 2 шт',
#        'Антисептик ULTRA MAX, концентрат, 1 кг, 2 шт',
#        'Гель эконом-класса для мытья  посуды вручную. С ароматом фруктовCooky Fruit Eконцентрированное средство / 5 л ПЭТ',
#        'Гель для мытья  посуды вручную. Без запахаCooky Fruit с ароматом фруктовконцентрированное средство / 0,5 л ',
#        'Антисептик\xa0 SAUNA, концентрат, 1 л, 2 шт',
#        'Средство для устранения засоров в трубахBath Profконцентрат 1:100 / 0,75 л',
#        'Средство для мытья стекол и зеркалOptic Crystalготовый состав / 1 л ',
#        'Дезинфицирующее средство ПРОФ ДЗ "PROF DZ" готовый состав / 5 л ',
#        'Универсальное моющее средство эконом - классаUniversal E концентрат 1:10-1:100 / 5 л',
#        'Чистящее средство, отбеливающий эффектCrystal Lux готовый состав / 0,4 л',
#        'Гель эконом-класса для мытья посуды вручную. С ароматом лимонаCooky Gel Lemon концентрированное средство / 5 л ПЭТ',
#        'Краска резиновая белый Ral 9003 / 12 кг',
#        'Средство для мытья посуды в посудомоечной машине. Для жесткой водыCooky Splash Softконцентрат 1:200-1:2000 / 20 л',
#        'Антисептик для влажной древесиныPROSEPT BiOконцентрат 1:19  / 30 л',
#        'Антисептик невымываемыйPROSEPT ECO ULTRAготовый состав / 65 л',
#        'Антисептик невымываемыйPROSEPT ULTRAкоричневый концентрат 1:10 / 30л',
#        'Антисептик  ECO ULTRA, коричневый / 65 л',
#        'Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый состав / 0,1 л',
#        'Кожный антисептик PROF DZ готовый состав / 0,05 л',
#        'Концентрат для мытья полов и стен  Multipower "Полевые цветы" 0,8 л',
#        'Антисептик лессирующий BiO LASUR / бесцветный / 2,7 л',
#        'Краска резиновая коричневый Ral 8017 / 12 кг',
#        'Краска резиновая серый Ral 7004 / 12 кг',
#        'Антисептик лессирующий BiO LASUR / белый люкс / 0,9 л',
#        'Антисептик лессирующий BiO LASUR / белый люкс / 2,7 л',
#        'Антисептик лессирующий BiO LASUR / бесцветный / 0.9 л',
#        'Антисептик лессирующий BiO LASUR / сосна / 0,9 л',
#        'Жидкое гель-мыло эконом-класса. Без красителей и ароматизаторовDiona Eготовый состав / 5 л ',
#        'Пенное мыло для дозаторов. С цветочным ароматомDiona Aromaконцентрат / 5 л ',
#        'Жидкое гель-мыло эконом-класса. Без красителей и ароматизаторовDiona Eготовый состав / 5 л ПЭТ',
#        'жидкое гель-мыло эконом-класса. C ароматом яблокаDiona Citrus Eготовое средство / 5 л ПЭТ',
#        'Жидкое гель-мыло с перламутром. C ароматом яблокаDiona Appleготовый состав / 5 л ПЭТ',
#        'Жидкое гель-мыло с перламутром. C ароматом цитрусовыхDiona Citrus готовый состав / 5 л ПЭТ',
#        'Антисептик лессирующий BiO LASUR / бук / 9 л',
#        'Нейтрализатор запаха с ароматом морского бризаFlox Sea I  готовый состав / 5 л ',
#        'Огнебиозащита ОГНЕБИО PROF 2 группа, бесцветный готовый состав / 65 л',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, бесцветный готовый состав / 30 л',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, красный готовый состав / 65 л',
#        'ОГНЕБИОЗАЩИТА  I группа, красный  готовый состав / 20 кг',
#        'Гель эконом-класса для мытья  посуды вручную. С ароматом яблокаCooky Apple Eконцентрированное средство / 5 л ПЭТ',
#        'Гель эконом-класса для мытья  посуды вручную. Без запахаCooky Е концентрированное средство / 5 л ПЭТ',
#        'Гелеобразное средство с антибактериальным эффектом для мытья посуды вручную. Без запахаCooky Plus концентрированное средство / 5 л ПЭТ',
#        'Гель для мытья  посуды вручную. Без запахаCooky Apple с ароматом яблокаконцентрированное средство / 0,5 л ',
#        'Средство для мытья посуды в посудомоечной машине. Для жесткой водыCooky Splash Softконцентрат 1:200-1:2000 / 10 л',
#        'Средство для мытья посуды в посудомоечной машине. Для жесткой водыCooky Splash Hard концентрат 1:200-1:2000 / 10 л',
#        'Средство для чистки акриловых поверхностейBath  Acryl концентрат 1:30-1:80 / 0,75 л',
#        'Пена для чистки ковров, мягкой мебели и текстиляCarpet Shampoo Активная пенаготовый состав / 0,4 л ',
#        'Концентрат для чистки и антимикробной обработки пищевого технологического оборудования Cooky Stuff концентрат 1:20-1:200 / 20 л',
#        'Концентрат для мытья полов и стен Multipower "Цитрус" концентрат / 0,8 л',
#        'Средство для удаления ржавчины и минеральных отложений щадящего действияBath Acid  концентрат 1:200-1:500 / 0,75 л ',
#        'Универсальное моющее и чистящее средствоUniversal Spray+концентрат 1:20-1:100 / 5 л',
#        'Стиральный порошок для белых тканейCrystal White + / 5 кг ПЭТ',
#        'Cтиральный порошок для цветных тканей с функцией "защита цвета" Crystal Color / 5 кг ПЭТ',
#        'Универсальное моющее средство эконом - классаUniversal E концентрат 1:10-1:100 / 1 л',
#        'Герметик акриловый цвет тик, 3 кг.',
#        'Средство для комплексного мытья и отбеливания поверхностей с дезинфицирующим эффектом.Duty Beliznaконцентрат 1:200-1:3000 / 5 л ',
#        'Кондиционер для белья с ароматом "Альпийская свежесть"Crystal Rinserконцентрат / 2 л ',
#        'Лак яхтный PROSEPT, полуматовыйготовый состав / 2 л',
#        'Шампунь-гель для душа 2 в 1 Ivee, 5 л',
#        'Лак яхтный PROSEPT, глянцевыйготовый состав / 2 л ',
#        'Лак яхтный PROSEPT, глянцевый,готовый состав / 0,9 л ',
#        'Антисептик  ECO EXTERIOR / 10 л',
#        'Средство для удаления гипсовой пылиDuty Whiteконцентрат 1:10-1:100 / 5 л  ',
#        'Антисептик ECO ULTRA, коричневый / 10 л',
#        'Удалитель плесени FUNGI CLEAN концентрат 1:1 / 5 л',
#        'Антисептик  ECO ULTRA, коричневый / 20 л',
#        'Удалитель мха концентрат 1:1 / 1 л ',
#        'Удалитель мха готовый состав / 5 л ',
#        'Удалитель плесени FUNGI CLEAN концентрат 1:1 / 1 л',
#        'Защита от плесени FUNGI STOP концентрат  1:10 / 1 л',
#        'Защитная пропитка от мхаконцентрат 1:10 / 5 л ',
#        'Шампунь-гель для душа 2 в 1 Alifee, 5 л',
#        'Набор для бани (Universal Wood, Multipower Wood)',
#        'Антисептик ECO ULTRA коричневый / 5 л',
#        'Отбеливатель для древесиныPROSEPT ECO 50готовый состав / 5 л',
#        'Лак яхтный PROSEPT, полуматовый,готовый состав / 0,9 л',
#        'Отбеливатель для древесиныPROSEPT ECO 50готовый состав / 10 л',
#        'Защита от плесени FUNGI STOP концентрат  1:10 / 5 л',
#        'Удалитель мха готовый состав / 1 л ',
#        'Отбеливатель для древесиныPROSEPT ECO 50готовый  состав / 1 кг',
#        'Удалитель плесени FUNGI CLEAN готовый состав / 0,5 л',
#        'Лак для камня PROSEPTготовый состав / 0,9 л',
#        'Набор для люстр Anti-Dust спрей, 0.5 л, 2 шт',
#        'Шампунь для чистки ковров и мягкой мебелиCarpet Shampooконцентрат 1:20-1:120 / 1 л',
#        'Лак для бани и сауны PROSEPTготовый состав / 0,9 л ',
#        'Средство для чистки люстр Universal Anti-dust готовый состав / 0,5 л',
#        'Средство для удаления клейкой ленты, клея, наклеекDuty Universalготовый состав / 2 л',
#        'Набор для люстр Anti-Dust спрей, 0.5 л, 3 шт',
#        'Средство для удаления наклеек Duty Universal / 210мл',
#        'Шампунь для сухой чистки ковров и текстильных изделийCarpet DryClean концентрат 1:20-1:100 / 0,5 л',
#        'Шампунь для сухой чистки ковров и текстильных изделийCarpet DryClean концентрат 1:20-1:100 / 1 л',
#        'Шампунь для чистки ковров и мягкой мебелиCarpet Shampooконцентрат 1:20-1:120 / 5 л',
#        'Лак для камня PROSEPTготовый состав / 2 л',
#        'Лак для бани и сауны PROSEPTготовый состав / 2 л ',
#        'Герметик акриловый цвет орех, ф/п 600мл (12 штук )',
#        'Герметик акриловый цвет медовый, 15 кг.',
#        'Герметик акриловый цвет орех, ф/п 600мл',
#        'Герметик акриловый цвет сосна, 15 кг.',
#        'Герметик акриловый цвет орех, 15 кг.',
#        'Герметик акриловый  цвет сосна, ф/п 600мл (12 штук )',
#        'Кондиционер для белья с ароматом Японского чаяCrystal Rinserконцентрат / 5 л ',
#        'Кондиционер для белья с ароматом  королевского ИрисаCrystal Rinserконцентрат / 5 л ',
#        'Кондиционер для белья с ароматом "Альпийская свежесть"Crystal Rinserконцентрат / 5 л ',
#        'Герметик акриловый цвет медовый, ф/п 600мл',
#        'Герметик акриловый  цвет белый , ф/п 600 мл. (12 штук )',
#        'Герметик акриловый цвет белый, 15 кг.',
#        'Кондиционер для белья с ароматом лепестков СакурыCrystal Rinserконцентрат / 5 л ',
#        'Кондиционер для белья без красителей и ароматизаторов Crystal Rinserконцентрат / 5 л ',
#        'Кондиционер для белья с ароматом экзотических цветовCrystal Rinserконцентрат / 5 л ',
#        'Кондиционер для белья с ароматом экзотических цветовCrystal Rinserконцентрат / 2 л ',
#        'Набор Антисептик-грунт ОSB BASE, 1 л, 2 шт',
#        'Антисептик-грунт OSB BASE готовый состав / 1 л',
#        'Кондиционер для белья с ароматом Японского чаяCrystal Rinserконцентрат / 2 л ',
#        'Набор Multipower Wood, 1 л, 2шт',
#        'Антисептик-грунт OSB BASE готовый состав / 10 л',
#        'Набор Universal Wood спрей, 0.5 л, 2шт',
#        'Средство для мытья плитки и керамогранитаMultipower Keramaконцентрат  / 5 л',
#        'Средство для мытья плитки и керамогранитаMultipower Keramaконцентрат  / 1 л',
#        'Моющее средство для бани и сауныMultipower Wood концентрат / 1 л',
#        'Спрей для очистки полков в банях и саунах Universal Woodготовый состав / 0,5л',
#        'Кондиционер для белья без красителей и ароматизаторов Crystal Rinserконцентрат / 2 л ',
#        'Удалитель ржавчины RUST REMOVER концентрат  1:2 / 5 л',
#        'Антисептик усиленный невымываемыйPROSEPT ULTRA MAXконцентрат 1:10 / 5 кг',
#        'Отбеливатель для древесиныPROSEPT 50концентрат 1:1 / 1 л',
#        'Антисептик усиленный невымываемыйPROSEPT ULTRA MAXконцентрат 1:10 / 1 кг',
#        'Антисептик универсальный для наружных и внутренних работPROSEPT UNIVERSALконцентрат 1:10 / 1 л',
#        'Антисептик против грибка и плесени АНТИПЛЕСЕНЬ готовый состав / 10 л',
#        'Антисептик против грибка и плесени АНТИПЛЕСЕНЬ готовый состав / 5 л',
#        'Отбеливатель для древесиныPROSEPT 50концентрат 1:1 / 10 л',
#        'Отбеливатель для древесиныPROSEPT 50концентрат 1:1 / 20 л',
#        'Антисептик универсальный для наружных и внутренних работPROSEPT UNIVERSALконцентрат 1:10 / 20 л',
#        'Антисептик универсальный для наружных и внутренних работPROSEPT UNIVERSALконцентрат 1:10 / 5 л',
#        'Средство для ухода за мебелью (полироль)Universal Polish  готовый состав / 0,5 л ',
#        'Спрей для столешниц и раковин из искусственного камня и гранитаCooky Spray  готовый состав / 0,5 л',
#        'Моющий концентрат для удаления индустриальных загрязненийDuty General концентрат 1:10-1:80 / 5 л',
#        'Нейтрализатор неприятных запаховFLOX PROFготовый состав / 0,5 л ',
#        'Концентрат эконом-класса для мытья половMultipower E (цитрус)  концентрат 1:5-1:150 / 5 л',
#        'Концентрат эконом-класса для мытья половMultipower E (цитрус)  концентрат 1:5-1:150 / 1 л',
#        'Средство для удаления жировых загрязнений. Без растворителейDuty Careконцентрат 1:4-1:65 / 5 л',
#        'Средство для снятия обоев спрей / 1 л',
#        'Концентрат эконом-класса для мытья половMultipower Eконцентрат 1:5-1:150 / 5 л',
#        'Средство для мытья полов всех типов PROSEPT Multipower E, 1 л.',
#        'Нейтрализатор неприятных запаховFLOX PROFготовый состав / 5 л ',
#        'Универсальное средство на основе ЧАС с дезинфицирующим эффектомUN-DZготовый состав / 0,5 л',
#        'Спрей для очистки каминных стекол от сажи и копоти Universal Hard 0,5 л',
#        'Спрей для очистки каминных стекол от сажи и копотиUniversal Hard готовый состав / 0,5 л',
#        'Жидкое гель-мыло с перламутром. Без цвета, без запахаDiona готовый состав / 5 л ',
#        'Антибактериальное мылоDiona Antibacготовое средство / 0,5 л ',
#        'Нейтрализатор неприятных запаховFlox «Чарующий Стамбул» готовый состав / 0,4 л ',
#        'Антибактериальное мылоDiona Antibacготовое средство / 5 л ',
#        'Удалитель ржавчины RUST REMOVER готовый состав / 0,5 л',
#        'Нейтрализатор неприятных запаховFlox «Романтичный Прованс» готовый состав / 0,4 л ',
#        'Нейтрализатор запаха с ароматом морского бризаFlox Sea I  готовый состав / 0,5 л ',
#        'Универсальное средство на основе ЧАС с дезинфицирующим эффектомUN-DZготовый состав / 5 л',
#        'Нейтрализатор неприятных запаховFlox «Солнечная Тоскана» готовый состав / 0,4 л ',
#        'Грунт по старой краске готовый состав / 2,5 кг',
#        'Универсальный пятновыводительCandyготовый состав / 5 л ',
#        'Краска для плит OSB для внутренних и наружных работSuper Elastic / 7 кг',
#        'Очиститель эпоксидного налетаEpoxy Cleanerготовый состав / 0,5 л ',
#        'Краска-грунт фасадная для плит OSB Proff 3 в 1 Liquid Rubber / 7 кг',
#        'Грунт БЕТОНКОНТАКТготовый состав / 3 кг',
#        'Краска для плит OSB для внутренних и наружных работSuper Elastic / 14 кг',
#        'Грунт БЕТОНКОНТАКТготовый состав / 1,3 кг',
#        'Универсальный пятновыводительCandyготовый состав / 0,5 л ',
#        'Краска-грунт фасадная для плит OSB Proff 3 в 1 Liquid Rubber / 14 кг',
#        'Краска-грунт фасадная для плит OSB Proff 3 в 1 Liquid Rubber / 1 кг',
#        'Очиститель эпоксидного налетаEpoxy Cleanerконцентрат 1:2 / 1 л ',
#        'Шпатлевка-замазка для заделки глубоких выбоин и трещинPlastix / 5 кг',
#        'Шпатлевка-замазка для заделки глубоких выбоин и трещинPlastix / 1,4 кг',
#        'Шпатлевка для плит OSBProplast / 1,3 кг',
#        'Средство для мытья и восстановления полов с полимерным покрытиемMultipower Polish концентрат 1:8-1:20 / 5 л',
#        'Полимерное покрытие для пола(сухой остаток 20%)Polish 250готовый состав / 5 л ',
#        'Шпатлевка-замазка для заделки швов по монтажной пене Flastic / 1,4 кг',
#        'Шпатлевка-замазка для заделки швов по монтажной пене Flastic / 5 кг',
#        'Защитная пропитка от мхаконцентрат 1:10 / 1 л ',
#        'Средство для чистки гриля и духовых шкафовCooky Grill Gelконцентрированное средство 1:1 – 1:50 / 1 л',
#        'Полимерное покрытие для пола(сухой остаток 20%)Polish 200 готовый состав / 5 л ',
#        'Шпатлевка для плит OSBProplast / 7 кг',
#        'Краска для плит OSB для внутренних и наружных работSuper Elastic / 1 кг',
#        'Универсальный концентрат для санитарных комнат с антимикробным эффектомBath Uni готовый состав / 0,5 л',
#        'Универсальный спрей для санитарных комнат Bath Spray готовый состав / 0,5 л',
#        'Очиститель для нержавеющей стали и цветных металловUniversal Cleanготовый состав / 0,5 л',
#        'Средство для уборки и дезинфекции санитарных комнатBath DZ Концентрат 1:8-1:100 / 1 л ',
#        'Средство для мытья стекол и зеркалOptic Crystalготовый состав / 0,5 л ',
#        'Средство для мытья стекол и зеркал с антистатическим эффектом      Optic Shineконцентрат 1:50-1:100 / 0,5 л ',
#        'Средство для чистки акриловых поверхностейBath  Acryl концентрат 1:30-1:80 / 1 л',
#        'Грунт АКВАИЗОЛ, голубой, концентрат  1:4 / 3 л',
#        'Средство для удаления ржавчины и минеральных отложений щадящего действияBath Acid концентрат 1:200-1:500 / 1 л ',
#        'Средство усиленного действия для удаления ржавчины и минеральных отложений Bath Acid +  концентрат 1:200-1:500 / 1 л ',
#        'Средство для удаления плесени  с дезинфицирующим эффектомBath Fungi концентрат 1:50-1:100 / 0,5 л',
#        'Гель для мытья  посуды вручную. Без запахаCookyконцентрированное средство / 1 л ',
#        'Гелеобразное средство усиленного действия для удаления ржавчины и минеральных отложенийBath Extraконцентрат 1:10-1:100 / 5 л',
#        'Средство для чистки гриля и духовых шкафовCooky Grill концентрированное средство / 0,55 л',
#        'Гелеобразное средство усиленного действия для удаления ржавчины и минеральных отложенийBath Extraконцентрат 1:10-1:100 / 0,75 л',
#        'Гель для мытья  посуды вручную. Без запахаCooky Fruit с ароматом фруктовконцентрированное средство / 1 л ',
#        'Средство для устранения засоров в трубахBath Profконцентрат 1:100 / 1 л',
#        'Гель для мытья  посуды вручную. Без запахаCookyконцентрированное средство / 5 л ',
#        'Средство для мытья и отбеливания посуды с дезинфицирующим эффектом.Cooky Whiteконцентрат 1:50-1:100 / 5 л',
#        'Средство для мытья стекол и зеркалOptic C+концентрат 1:50-1:100 / 5 л ',
#        'Средство для мытья стекол и зеркал с антистатическим эффектом      Optic Shineконцентрат 1:50-1:100 / 5 л ',
#        'Гель для мытья  посуды вручную. Без запахаCooky Apple с ароматом яблокаконцентрированное средство / 1 л ',
#        'Средство для мытья полов всех типовMultipower Neutral концентрат 1:64 - 1:500 / 1 л',
#        'Средство для мытья стекол и зеркалOptic Crystalготовый состав / 5 л ',
#        'Антисептик невымываемыйPROSEPT ECO ULTRAготовый состав / 20 л',
#        'Средство для мытья посуды в посудомоечной машине. Для жесткой водыCooky Splash Softконцентрат 1:200-1:2000 / 5 л',
#        'Грунт АКВАИЗОЛ, розовый, концентрат  1:9 / 3 л',
#        'Грунт АКВАИЗОЛ, влагоизолирующий,готовый состав / 3 л',
#        'Усиленное чистящее средство с антистатическим эффектомUniversal Spray Активная пенаготовый состав / 0,4 л',
#        'Гелеобразный концентрат для мытья посуды в посудомоечных машинах. Для воды любой степени жесткостиSplash Limeконцентрат / 1 л ',
#        'Универсальное моющее и чистящее средствоUniversal Sprayготовый состав / 5 л',
#        'Средство для мытья посуды в посудомоечной машине. Для жесткой водыCooky Splash Hard концентрат 1:200-1:2000 / 5 л',
#        'Антисептик невымываемыйPROSEPT ECO ULTRAготовый состав / 10 л',
#        'Грунт АКВАИЗОЛ, розовый, концентрат  1:9 / 1 л',
#        'Жидкое моющее средство для стирки спортивной одежды, обуви и пуховиковCrystal Sportконцентрат / 1 л ',
#        'Жидкий моющий концентрат для стирки белья  Crystal концентрат / 3 л ',
#        'Жидкое моющее средство для стирки белых и светлых тканейCrystal Blackконцентрат / 1 л ',
#        'Жидкое моющее средство для стирки белых и светлых тканейCrystal Blackконцентрат / 3 л ',
#        'Жидкое моющее средство для стирки спортивной одежды, обуви и пуховиковCrystal Sportконцентрат / 3 л ',
#        'Средство усиленного действия для мытья всех типов половMultipower Profконцентрат 1:20 -1:300 / 1 л ',
#        'Средство для мытья светлых полов с отбеливающим эффектомMultipower Whiteконцентрат 1:20-1:200 / 5 л',
#        'Средство усиленного действия для мытья всех типов половMultipower Profконцентрат 1:20 -1:300 / 5 л ',
#        'Жидкий моющий концентрат для стирки белья  с ароматом алоэ вераCrystal концентрат / 3 л ',
#        'Грунт АКВАИЗОЛ, голубой, концентрат  1:4 / 1 л',
#        'Антисептик универсальный ХМФ-БФ, ГОСТ / 10 л',
#        'Антисептик трудновымываемый ХМББ, ГОСТ / 5 л',
#        'Антисептик для влажной древесиныPROSEPT BiOконцентрат 1:19  / 1 л',
#        'Антисептик трудновымываемый ХМББ, ГОСТ / 10 л',
#        'Антисептик  ECO UNIVERSAL  / 10 л',
#        'Жидкий моющий концентрат для стирки белья  с ароматом белых цветовCrystal концентрат / 3 л ',
#        'Антисептик для влажной древесиныPROSEPT BiOконцентрат 1:19 / 20 л',
#        'Антисептик  ECO UNIVERSAL / 5 л',
#        'Антисептик против жуков и других биопоражении АНТИЖУК / 10 л',
#        'Антисептик универсальный ХМФ-БФ, ГОСТ / 5 л',
#        'Жидкое моющее средство для стирки белых и светлых тканейCrystal Whiteконцентрат / 1 л ',
#        'Антисептик для влажной древесиныPROSEPT BiOконцентрат 1:19 / 5 л',
#        'Антисептик  ECO EXTERIOR / 5 л',
#        'Жидкое моющее средство для стирки белых и светлых тканейCrystal Whiteконцентрат / 3 л ',
#        'Краска резиновая серый Ral 7004 / 3 кг',
#        'Очиститель фасадов SALT CLEANER концентрат 1:2 / 5 л',
#        'Антисептик для внутренних работ ECO INTERIOR / 10 л',
#        'Сухой концентрат огнебиозащита мешок / 16 кг',
#        'Антисептик для внутренних работ ECO INTERIOR/ 5 л',
#        'Краска резиновая зеленый мох Ral 6005 / 3 кг',
#        'Средство для удаления граффити, маркера, краскиDuty Graffiti готовый состав, аэрозоль / 0,4 л',
#        'Средство для мытья фасадов и дорожных покрытийDuty Hard +   концентрат / 1 л ',
#        'Средство для мытья полов всех типовMultipower Neutral концентрат 1:64 - 1:500 / 5 л',
#        'Средство для мытья фасадов и дорожных покрытийDuty Hard +   концентрат / 5 л',
#        'Средство для удаления граффити, маркера, краскиDuty Graffiti готовый состав, аэрозоль / 2 л',
#        'Краска резиновая зеленый мох Ral 6005 / 1 кг',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, красный готовый состав / 5 л',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, красный готовый состав / 20 л',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, бесцветный готовый состав / 20 л',
#        'Огнебиозащита ОГНЕБИО PROF 2 группа, бесцветный готовый состав / 20 л',
#        'Антисептик для внутренних работPROSEPT SAUNAконцентрат 1:10 / 5 л',
#        'Краска резиновая серый Ral 7004 / 1 кг',
#        'Краска резиновая коричневый Ral 8017 / 1 кг',
#        'Краска резиновая белый Ral 9003 / 3 кг',
#        'Краска резиновая черный Ral 9004  / 1 кг',
#        'Краска резиновая черный Ral 9004  / 3 кг',
#        'Огнебиозащита ОГНЕБИО PROF 2 группа, красный готовый состав / 20 л',
#        'Средство для изделий из кожи, очистка и уходDuty Leather готовый состав, аэрозоль / 0,4 л ',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, бесцветный готовый состав / 10 л',
#        'Антисептик для внутренних работPROSEPT INTERIORконцентрат 1:10 / 5 л',
#        'Антисептик многофункциональный ФБС, ГОСТ / 5 л',
#        'Масло для защиты полков в саунах и банях SAUNA OIL / 0,25 л',
#        'Антисептик невымываемыйPROSEPT ULTRAкоричневый концентрат 1:10 / 20л',
#        'Антисептик для внутренних работPROSEPT INTERIORконцентрат 1:10 / 1 л',
#        'Антисептик многофункциональный ФБС, ГОСТ / 10 л',
#        'Антисептик невымываемыйPROSEPT ULTRAкоричневый концентрат 1:10 / 5 л',
#        'Антисептик трудновымываемый для наружных работ PROSEPT EXTERIORконцентрат 1:19 / 20 л',
#        'Масло для защиты полков в саунах и баняхPROSEPT SAUNA OILготовый  состав  /  1 л',
#        'Антисептик трудновымываемый для наружных работ PROSEPT EXTERIORконцентрат 1:19 / 1 л',
#        'ОГНЕБИОЗАЩИТА  I группа, бесцветный готовый состав / 10 кг',
#        'ОГНЕБИОЗАЩИТА для древесины 2 группа, красный готовый  состав / 10 кг',
#        'Удалитель цемента CEMENT CLEANER концентрат 1:2 / 1 л',
#        'Антисептик для бани и сауны ECO SAUNA готовый состав / 5 л',
#        'PROSEPT огнебиозащита для древесины с цветовой индикацией. Высшая (1-ая) группа, 20л.',
#        'Антисептик невымываемыйPROSEPT ULTRAконцентрат 1:10  / 5 л',
#        'Антисептик для бани и сауны ECO SAUNAготовый состав / 10 л',
#        'Антисептик невымываемыйPROSEPT ULTRAконцентрат 1:10 / 20 л',
#        'Антисептик невымываемый ХМ-11, ГОСТ / 5 л',
#        'Удалитель цемента CEMENT CLEANER концентрат 1:2 / 5 л',
#        'Антисептик невымываемый ХМ-11, ГОСТ / 10 л',
#        'ОГНЕБИОЗАЩИТА I группа, красный  готовый состав / 10 кг',
#        'ОГНЕБИОЗАЩИТА для древесины 2 группа, бесцветный  готовый состав / 10 кг',
#        'Универсальный концентрат для мытья половMultipower FLOOR концентрат 1:10-1:200 / 1 л',
#        'Универсальный пенный обезжириватель для  пищевого  производства с антимикробным эффектомDuty Foamконцентрат 1:20-1:100 / 5 л ',
#        'Концентрат для мытья половMULTIPOWER с ароматом цитрусаконцентрат / 1 л',
#        'Средство для удаления напольных защитных покрытийDuty Stripperконцентрат 1:20-1:50 / 5 л',
#        'Средство для обезжиривания поверхностей и удаления стойких запаховDuty Citrus концентрат 1:1-1:30 / 5 л',
#        'Средство для обезжиривания поверхностей и удаления стойких запаховDuty Citrus концентрат 1:1-1:30 / 1 л',
#        'ОГНЕБИОЗАЩИТА для древесины 2 группа, красный готовый состав / 20 кг',
#        'Универсальный концентрат для мытья половMultipower FLOOR концентрат 1:10-1:200 / 5 л',
#        'Средство для уборки и дезинфекции санитарных комнатBath DZ Концентрат 1:8-1:100 / 5 л ',
#        'Жидкое моющее средство для стирки цветных тканейCrystal Colorконцентрат / 3 л ',
#        'Усиленное средство для уборки после строительстваDuty Extra Plusконцентрат 1:2-1:120 / 5 л ',
#        'Герметик акриловый цвет Медовый, 15 кг',
#        'Краска резиновая коричневый Ral 8017 / 3 кг',
#        'Средство для чистки производственных помещений и оборудования с дезинфицирующим эффектомDuty Hard концентрат 1:2-1:60 / 1 л',
#        'Лак паркетный  PROSEPT, глянцевый,готовый состав / 0,9л',
#        'Жидкое моющее средство для стирки шерсти, шелка и деликатных тканейCrystal Delicateконцентрат / 3 л ',
#        'Универсальное моющее средствоUniversal Prof  концентрат 1:10 - 1:200 / 1 л',
#        'Средство для удаления ржавчины и минеральных отложений щадящего действияBath Acid концентрат 1:200-1:500 / 5 л ',
#        'Средство для чистки производственных помещений и оборудования с дезинфицирующим эффектомDuty Hard концентрат 1:2-1:60 / 5 л',
#        'Лак интерьерный PROSEPTготовый состав / 0,9 л',
#        'Лак паркетный  PROSEPT, полуматовый,готовый состав / 0,9 л',
#        'Лак интерьерный PROSEPTготовый состав / 2 л',
#        'Пропитка для камня AQUAISOL концентрат  1:2 / 5 л',
#        'Хлорные таблетки с антибактериальным эффектомTAB-DZ / 1 кг',
#        'Средство усиленного действия для удаления ржавчины и минеральных отложений Bath Acid + концентрат 1:200-1:500 / 5 л ',
#        'Средство для уборки после строительстваDuty Extraконцентрат 1:2-1:100 / 1 л ',
#        'Средство для уборки после строительстваDuty Extraконцентрат 1:2-1:100 / 5 л ',
#        'Универсальное моющее средствоUniversal Prof  концентрат 1:10 - 1:200 / 5 л',
#        'Универсальное моющее средство с дезинфицирующим эффектомUniversal DZ концентрат 1:10- 1:120 / 5 л',
#        'Универсальный концентрат для санитарных комнат с антимикробным эффектомBath Uni готовый состав / 5 л',
#        'Средство для уборки и дезинфекции санитарных комнатBath DZ Концентрат 1:8-1:100 / 0,75 л ',
#        'Средство для чистки акриловых поверхностейBath  Acryl концентрат 1:30-1:80 / 5 л',
#        'Универсальное моющее средство с дезинфицирующим эффектомUniversal DZ концентрат 1:10- 1:120 / 1 л',
#        'Cредство для чистки коптильных камерCooky Smokeконцентрат 1:10-1:100 / 5 л',
#        'Грунт УКРЕПЛЯЮЩИЙготовый состав / 10 л',
#        'Грунт УКРЕПЛЯЮЩИЙготовый состав / 3 л',
#        'Чистящий крем для кухниCooky Universal  "ледяная свежесть"готовый состав / 0,5 л ',
#        'Ополаскиватель для пароконвектоматов с режимом автомат. ОчисткиSplash Shine концентрат / 5 л',
#        'Специальная соль для посудомоечных машин Splashготовый состав / 1,5 кг',
#        'Средство для чистки гриля и духовых шкафовCooky Grill Gelконцентрированное средство 1:1 – 1:50 / 5 л',
#        'Средство для удаления плесени  с дезинфицирующим эффектомBath Fungi концентрат 1:50-1:100 / 5 л',
#        'Ополаскиватель для посудомоечных машин всех типовSplash Rinserконцентрат / 0,8 л ',
#        'Чистящий крем для кухниCooky Universal с ароматом цитруса готовый состав / 0,5 л ',
#        'Концентрат для чистки и антимикробной обработки пищевого технологического оборудования Cooky Stuff концентрат 1:20-1:200 / 5 л',
#        'Средство для чистки гриля и духовых шкафовCooky Grill концентрированное средство / 5 л',
#        'Грунт УНИВЕРСАЛЬНЫЙ, пропиточныйготовый состав / 3 л',
#        'Пропитка для камня  AQUAISOL концентрат  1:2 / 1 л',
#        'Удалитель ржавчины RUST REMOVER концентрат 1:2 / 1 л',
#        'Герметик акриловый цвет Медовый, 7 кг',
#        'Антисептик трудновымываемый для наружных работ PROSEPT EXTERIORконцентрат 1:19 / 5 л',
#        'Удалитель цемента CEMENT CLEANER готовый состав / 0,5 л',
#        'Защита от плесени FUNGI STOP готовый состав / 0,5 л',
#        'Средство для удаления клейкой ленты, клея, наклеекDuty Universalготовый состав / 400мл',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, красный готовый состав / 10 л',
#        'Герметик акриловый цвет Орех, 7 кг',
#        'Антисептик невымываемыйPROSEPT ECO ULTRAготовый состав / 5 л',
#        'Герметик акриловый цвет Сосна, 7 кг',
#        'Средство для устранения засоров в трубахBath Profконцентрат 1:100 / 5 л',
#        'Гелеобразное средство усиленного действия для удаления ржавчины и минеральных отложенийBath Extraконцентрат 1:10-1:100 / 1 л',
#        'Средство для снятия обоев  концентрат  1:19 / 0,5 л',
#        'Очиститель фасадов SALT CLEANER концентрат 1:2 / 1 л',
#        'Антисептик-грунт OSB BASE готовый состав / 5 л',
#        'Грунт АКВАИЗОЛ, влагоизолирующий,готовый состав / 10 л',
#        'Антисептик против жуков и других биопоражении АНТИЖУК / 5 л',
#        'Краска резиновая белый Ral 9003 / 1 кг',
#        'Грунт УНИВЕРСАЛЬНЫЙ, пропиточныйготовый состав / 10 л',
#        'Средство для удаления гипсовой пылиDuty Whiteконцентрат 1:10-1:100 / 1 л  ',
#        'Добавка против появления плесени / 0,25 л',
#        'Универсальное моющее и чистящее средствоUniversal Sprayготовый состав / 0,5 л',
#        'Кислотный ополаскиватель для посудомоечных машинSplash Rinserконцентрат 1:200-1:3000 / 5 л ',
#        'Жидкое моющее средство для стирки цветных тканейCrystal Colorконцентрат / 1 л ',
#        'Средство для уборки помещений после пожара с дезинфицирующим эффектомDuty Blackконцентрат 1:20-1:50 / 5 л',
#        'Жидкое моющее средство для стирки шерсти, шелка и деликатных тканейCrystal Delicateконцентрат / 1 л ',
#        'Средство для чистки гриля и духовых шкафовCooky Grill Gelконцентрированное средство 1:1 – 1:50 / 0,5 л',
#        'Средство для мытья полов с полимерным покрытиемMultipower Bright концентрат 1:65-1:500 / 5 л',
#        'Средство усиленного действия для удаления ржавчины и минеральных отложений Bath Acid +  концентрат 1:200-1:500 / 0,75 л '],
#       dtype=object)

# %% [markdown]
# В наименованих иногда пропущены пробелы между слов. Необходимо добавить пропущенные пробелы в наименования товаров в столбцах 'name', 'name_1c', 'ozon_name' и 'wb_name'.

# %%
columns_to_apply = ['name', 'name_1c', 'ozon_name', 'wb_name']

data_products[columns_to_apply] = data_products[columns_to_apply].astype(str).applymap(add_spaces)

# %% [markdown]
# Поскольку в названиях товаров присутствуют обьем, количество штук в упаковке и концентрация продукция. Также у каждого обьема разная единица измерения. Эти данные можно извлечь и зафиксировать в отдельные столбцы в качестве дополнительных признаков.

# %%
data_products = extract_info(data_products)

# %% [markdown]
# При анализе уникальных значений в столбце name обнаружено, что есть лишний пробел в слове Средство. Посмотрим, много ли таких позиций и произведем удаление этого пробела в слове.

# %%
# Создание фильтра, который проверяет, содержит ли каждая строка в столбце 'name' подстроку "C редство"
filter = data_products['name'].str.contains('C редство')

# Применение фильтра к датафрейму для вывода только строк, которые соответствуют фильтру
data_products[filter]
# Out:
#       id   article                                               name  \
# 28    78    143-20  C редство для чистки коптильных камер Cooky Sm...
# 46   182  P1 11005  C редство для рук гигиеническое с антибактериа...
# 47   181  P1 11800  C редство для рук гигиеническое с антибактериа...
# 452   77     143-5  C редство для чистки коптильных камер Cooky Sm...
#
#         cost  recommended_price  category_id  \
# 28   2781.00             6496.0         49.0
# 46    565.00             1319.0          NaN
# 47    155.00              361.0          NaN
# 452   726.52             1696.0         40.0
#
#                                              ozon_name  \
# 28   C редство для чистки коптильных камер Cooky Sm...
# 46                                                 nan
# 47                                                 nan
# 452  Профессиональное средство для чистки коптильны...
#
#                                                name_1c  \
# 28   C редство для чистки коптильных камер Cooky Sm...
# 46                                                 nan
# 47                                                 nan
# 452  Профессиональное средство для чистки коптильны...
#
#                                                wb_name volume units_of_meas  \
# 28   C редство для чистки коптильных камер Cooky Sm...     20             л
# 46                                                 nan      5             л
# 47                                                 nan    0,8             л
# 452  Профессиональное средство для чистки коптильны...      5             л
#
#     concent units
# 28     1:10     1
# 46      1:1     1
# 47      1:1     1
# 452    1:10     1

# %%
data_products['ozon_name'] = data_products['ozon_name'].str.replace('C редство', 'Средство')
data_products['name_1c'] = data_products['name_1c'].str.replace('C редство', 'Средство')
data_products['wb_name'] = data_products['wb_name'].str.replace('C редство', 'Средство')
data_products['name'] = data_products['name'].str.replace('C редство', 'Средство')

# %% [markdown]
# Так же в наименования оказались еще места, которые не были обработаны функцией и уберем эти проблемы вручную.

# %%
data_products['name'] = data_products['name'].str.replace('БЕТОНКОНТАКТготовый', 'БЕТОНКОНТАКТ готовый')
data_products['name'] = data_products['name'].str.replace('"к', '" к')
data_products['name'] = data_products['name'].str.replace('яблокаконцентрированное', 'яблока концентрированное')
data_products['name'] = data_products['name'].str.replace('(сухой остаток 20%)', ' (сухой остаток 20%) ')
data_products['name'] = data_products['name'].str.replace('.C', '. C')

# %% [markdown]
# Проверим результаты обработки.

# %%
data_products['name'].unique()
# Out:
# array(['Антисептик невымываемый PROSEPT ULTRA концентрат 1:10  / 1 л',
#        'Антигололед - 32 PROSEPT готовый состав / 12 кг',
#        'Герметик акриловый цвет сосна, ф/п 600 мл',
#        'Кондиционер для белья с ароматом  королевского Ириса Crystal Rinser концентрат / 2 л ',
#        'Герметик акриловой  цвет Белый, 7 кг',
#        'Грунт БЕТОНКОНТАКТ готовый состав / 6 кг',
#        'Грунт БЕТОНКОНТАКТ готовый состав / 12 кг',
#        'Средство для удаления технических масел, смазочных материалов и нефтепродуктов Duty Oil концентрат 1:20-1:150 /  5 л',
#        'Антисептик универсальный суперсильный',
#        'Средство для мытья светлых полов с отбеливающим эффектом Multipower White концентрат 1:20-1:200 / 1 л',
#        'Отбеливатель для древесины PROSEPT 50 концентрат 1:1 / 5 л',
#        'Антисептик лессирующий BiO LASUR / тик / 9 л',
#        'Антисептик лессирующий BiO LASUR / махагон / 0,9 л',
#        'Антисептик лессирующий BiO LASUR / лиственница / 0,9 л',
#        'Антисептик лессирующий BiO LASUR / тик / 0,9 л',
#        'Средство для мытья полов и стен Multipower "Полевые цветы" концентрат  1:10 – 1:120 / 0,8 л',
#        'Антисептик лессирующий BiO LASUR / тик / 2,7 л',
#        'Антисептик лессирующий BiO LASUR / махагон / 9 л',
#        'Антисептик лессирующий BiO LASUR / дуб / 2,7 л',
#        'Антисептик лессирующий BiO LASUR / палисандр / 0,9 л',
#        'Антисептик лессирующий BiO LASUR / палисандр / 2,7 л',
#        'Антисептик лессирующий BiO LASUR / палисандр / 9 л',
#        'Антисептик лессирующий BiO LASUR / орех / 9 л',
#        'Средство для мытья полов и стен Multipower "После дождя" концентрат 1:10 – 1:120 / 0,8 л',
#        'Гель для мытья  посуды вручную. Без запаха Cooky концентрированное средство / 0,5 л ',
#        'Средство усиленного действия для удаления ржавчины и минеральных отложений Bath Acid +  с ароматом цитрусаконцентрат 1:200-1:500 / 0,75 л',
#        'Герметик акриловый  цвет медовый ф/п 600 мл. (12 штук )',
#        'Средство для чистки коптильных камер Cooky Smoke концентрат 1:10-1:100 / 20 л',
#        'Гель эконом-класса для мытья посуды вручную. С ароматом лимона Cooky Gel Lemon концентрированное средство / 5 л ',
#        'Антибактериальное мыло Diona Antibac готовое средство / 5 л ПЭТ',
#        'Средство усиленного действия для чистки коптильных камер Duty Fog концентрат / 20 л',
#        'Средство низкопенное  для  очистки  алюминия и сплавов на его основе Duty Mud  концентрат / 20 л',
#        'Кондиционер для белья с ароматом лепестков Сакуры Crystal Rinser концентрат / 2 л ',
#        'Набор для посудомоечной посуды PROSEPT, 3 средства',
#        'Стиральный порошок для белых тканей Crystal White / 5 кг ПЭТ',
#        'Набор для стирки PROSEPT, 6 средств для всех типов тканей',
#        'Набор Удалитель мха, концентрат 1 л, 2 шт',
#        'Набор для посудомоечной посуды PROSEPT, 2 средства (гель и ополаскиватель)',
#        'Герметик акриловый цвет белый, ф/п 600 мл.',
#        'Огнебиозащита ОГНЕБИО PROF 2 группа бесцветный готовый состав / 10 л',
#        'Набор для посудомоечной посуды PROSEPT, 2 средства (ополаскиватель и соль)',
#        'Набор "Антиплесень" PROSEPT (удалитель плесени и защита от плесени)',
#        'жидкое гель-мыло эконом-класса. C ароматом яблока Diona Apple E готовое средство / 5 л ПЭТ',
#        'Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый состав / 0,05 л',
#        'Средство для рук гигиеническое с антибактериальным эффектом PROSEPT готовый состав / 5 л',
#        'Средство для рук гигиеническое с антибактериальным эффектом PROSEPT готовый состав / 0,8 л',
#        'Средство для мытья полов PROSEPT Multipower "Вершины Тибета", 2 штуки * 0.8 л.',
#        'Пенное мыло для дозаторов. Без красителей и ароматизаторов Diona Flower концентрат / 5 л ',
#        'Набор для удаления загрязнений и наклеек PROSEPT, 2 средства (универсальный спрей для уборки и удалитель наклеек)',
#        'Набор Удалитель мха, готовый состав, 1 л, 2 шт',
#        'Средство для удаления граффити, маркера, краски Duty Graffiti Max готовый состав, аэрозоль / 2 л',
#        'Огнебиозащита ОГНЕБИО PROF 2 группа, красный готовый состав / 10 л',
#        'Чистящее средство, сода эффект Crystal Hand готовый состав / 0,4 л',
#        'Антисептик невымываемый PROSEPT ULTRA коричневый концентрат 1:10 / 1 л',
#        'Антисептик для внутренних работ PROSEPT SAUNA концентрат 1:10 / 1 л',
#        'Пеногаситель Antifoam концентрат до 1:300 / 1 л ',
#        'Набор Краска для OSB плит TopTex, 1 кг, 2 шт',
#        'Кожный антисептик ПРОФ ДЗ "PROF DZ"готовый состав / 1 л',
#        'Жидкое мыло с антибактериальным компонентом для диспенсеров с пенообразователем Diona AN FOAM / 5 л',
#        'Герметик акриловый цвет тик, ф/п 600 мл',
#        'Средство для мытья полов PROSEPT Multipower "После дождя", 2 штуки * 0.8 л.',
#        'Набор Очиститель фасадов SALT CLEANER, 1 л, 2 шт',
#        'Набор Universal Hard спрей, 0.5 л, 2 шт',
#        'Концентрат для мытья полов и стен Multipower "Цитрус" 0,8 л',
#        'Огнебиозащита ОГНЕБИО PROF 2 группа, красный готовый состав / 65 л',
#        'ОГНЕБИОЗАЩИТА I группа, красный готовый состав / 65 кг',
#        'Набор Duty Universal, 0.4 л, 2 шт',
#        'Набор Flox Prof спрей, 0.5 л, 2 шт',
#        'Набор Лак яхтный, глянцевый, 0.9 л, 2 шт',
#        'Набор Лак яхтный, полуматовый, 0.9 л, 2 шт',
#        'Антисептик лессирующий BiO LASUR / бук / 0,9 л',
#        'Антисептик лессирующий BiO LASUR / орех / 0,9 л',
#        'Антисептик лессирующий BiO LASUR / лиственница / 9 л',
#        'Антисептик лессирующий BiO LASUR / дуб / 0,9 л',
#        'Антисептик лессирующий BiO LASUR / дуб / 9 л',
#        'Герметик акриловый цвет Белый, 15 кг',
#        'Герметик акриловый цвет Белый, 3 кг',
#        'Антисептик лессирующий BiO LASUR / сосна / 2,7 л',
#        'Набор Шпатлевка для OSB Proplast 1,3 кг, 2 шт',
#        'Герметик акриловый цвет Орех 0,6 л',
#        'Герметик акриловый цвет Орех, 15 кг',
#        'Герметик акриловый цвет Орех, 3 кг',
#        'Герметик акриловый цвет Сосна, 3 кг',
#        'Набор Duty Leather, 0.4 л, 2 шт',
#        'Набор DUTY GRAFFITI, 0.4 л, 2 шт',
#        'Набор Шпатлевка-замазка трещин Plastix 1,4 кг, 2 шт',
#        'Герметик акриловый цвет белый ф/п 600 мл. (12 штук )',
#        'Антигололед - 32 PROSEPT готовый состав / 6 кг',
#        'Концентрат для мытья полов и стен  Multipower "Полевые цветы" 0,8 л 2 ШТ',
#        'Концентрат для мытья полов и стен Multipower "Цитрус" 0,8 л 2 ШТ',
#        'Отбеливатель Prosept 50, концентрат, 1 л, 2 шт',
#        'Герметик акриловый цвет сосна, ф/п 600 мл (12 штук )',
#        'Герметик акриловый цвет Медовый, 3 кг',
#        'Краска резиновая зеленый мох Ral 6005 / 12 кг',
#        'Антисептик ULTRA, концентрат, 1 л, 2 шт',
#        'Средство для мытья полов и стен Multipower  "Вершины Тибета" концентрат  1:10 – 1:120 / 0,8 л',
#        'Антисептик невымываемый PROSEPT ULTRA концентрат  1:10  / 30 л',
#        'Средство для мытья посуды в посудомоечной машине. Для жесткой воды Cooky Splash Hard концентрат 1:200-1:2000 / 20 л',
#        'Герметик акриловый цвет Сосна, 15 кг',
#        'Кожный антисептик PROF DZ готовый состав / 0,1 л',
#        'Антисептик лессирующий BiO LASUR / бук / 2,7 л',
#        'Антисептик трудновымываемый для наружных работ PROSEPT EXTERIOR концентрат 1:19 / 30 л',
#        'Герметик акриловый цвет Медовый 0,6 л',
#        'Антисептик универсальный для наружных и внутренних работ PROSEPT UNIVERSAL концентрат 1:10 / 30 л',
#        'Антисептик невымываемый ХМ-11, ГОСТ / 20 л',
#        'ОГНЕБИОЗАЩИТА 2 группа, красный готовый состав / 65 кг',
#        'Герметик акриловый цвет Медовый 0,6 л (12 шт)',
#        'Герметик акриловый цвет Орех, ф/п 600 мл (12 штук )',
#        'Антисептик лессирующий BiO LASUR / махагон / 2,7 л',
#        'Антисептик  ECO UNIVERSAL / 65 л',
#        'Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый состав / 5 л ',
#        'Дезинфицирующее средство ПРОФ ДЗ "PROF DZ" готовый состав / 0,5 л ',
#        'Антисептик для рук PROSEPT PROF DZ, 2 штуки * 100 мл.',
#        'Моющее средство для пароконвектоматов с режимом автоматической очистки Cooky Degreaser концентрат / 5 л',
#        'Жидкое гель-мыло с перламутром. Без цвета, без запаха Diona готовый состав / 5 л ПЭТ',
#        'Антисептик лессирующий BiO LASUR / сосна / 9 л',
#        'Краска резиновая черный Ral 9004 / 12 кг',
#        'Антисептик лессирующий BiO LASUR / орех / 2,7 л',
#        'Антисептик лессирующий BiO LASUR / лиственница / 2,7 л',
#        'Антисептик лессирующий BiO LASUR / бесцветный / 9 л',
#        'Антисептик лессирующий BiO LASUR / белый люкс / 9 л',
#        'Отбеливатель для древесины PROSEPT 50 концентрат 1:1 / 30 л',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, красный готовый состав / 30 л',
#        'Огнебиозащита   ОГНЕБИО PROF l, 1 группа, бесцветный готовый состав / 65 л',
#        'Огнебиозащита ОГНЕБИО PROF I, 1 группа, бесцветный готовый состав / 5 л',
#        'Антисептик ULTRA коричневый, концентрат, 1 л, 2 шт',
#        'Антисептик ULTRA MAX, концентрат, 1 кг, 2 шт',
#        'Гель эконом-класса для мытья  посуды вручную. С ароматом фруктов Cooky Fruit E концентрированное средство / 5 л ПЭТ',
#        'Гель для мытья  посуды вручную. Без запаха Cooky Fruit с ароматом фруктовконцентрированное средство / 0,5 л ',
#        'Антисептик\xa0 SAUNA, концентрат, 1 л, 2 шт',
#        'Средство для устранения засоров в трубах Bath Prof концентрат 1:100 / 0,75 л',
#        'Средство для мытья стекол и зеркал Optic Crystal готовый состав / 1 л ',
#        'Дезинфицирующее средство ПРОФ ДЗ "PROF DZ" готовый состав / 5 л ',
#        'Универсальное моющее средство эконом - класса Universal E концентрат 1:10-1:100 / 5 л',
#        'Чистящее средство, отбеливающий эффект Crystal Lux готовый состав / 0,4 л',
#        'Гель эконом-класса для мытья посуды вручную. С ароматом лимона Cooky Gel Lemon концентрированное средство / 5 л ПЭТ',
#        'Краска резиновая белый Ral 9003 / 12 кг',
#        'Средство для мытья посуды в посудомоечной машине. Для жесткой воды Cooky Splash Soft концентрат 1:200-1:2000 / 20 л',
#        'Антисептик для влажной древесины PROSEPT BiO концентрат 1:19  / 30 л',
#        'Антисептик невымываемый PROSEPT ECO ULTRA готовый состав / 65 л',
#        'Антисептик невымываемый PROSEPT ULTRA коричневый концентрат 1:10 / 30 л',
#        'Антисептик  ECO ULTRA, коричневый / 65 л',
#        'Кожный антисептик ПРОФ ДЗ "PROF DZ" готовый состав / 0,1 л',
#        'Кожный антисептик PROF DZ готовый состав / 0,05 л',
#        'Концентрат для мытья полов и стен  Multipower "Полевые цветы" 0,8 л',
#        'Антисептик лессирующий BiO LASUR / бесцветный / 2,7 л',
#        'Краска резиновая коричневый Ral 8017 / 12 кг',
#        'Краска резиновая серый Ral 7004 / 12 кг',
#        'Антисептик лессирующий BiO LASUR / белый люкс / 0,9 л',
#        'Антисептик лессирующий BiO LASUR / белый люкс / 2,7 л',
#        'Антисептик лессирующий BiO LASUR / бесцветный / 0.9 л',
#        'Антисептик лессирующий BiO LASUR / сосна / 0,9 л',
#        'Жидкое гель-мыло эконом-класса. Без красителей и ароматизаторов Diona E готовый состав / 5 л ',
#        'Пенное мыло для дозаторов. С цветочным ароматом Diona Aroma концентрат / 5 л ',
#        'Жидкое гель-мыло эконом-класса. Без красителей и ароматизаторов Diona E готовый состав / 5 л ПЭТ',
#        'жидкое гель-мыло эконом-класса. C ароматом яблока Diona Citrus E готовое средство / 5 л ПЭТ',
#        'Жидкое гель-мыло с перламутром. C ароматом яблока Diona Apple готовый состав / 5 л ПЭТ',
#        'Жидкое гель-мыло с перламутром. C ароматом цитрусовых Diona Citrus готовый состав / 5 л ПЭТ',
#        'Антисептик лессирующий BiO LASUR / бук / 9 л',
#        'Нейтрализатор запаха с ароматом морского бриза Flox Sea I  готовый состав / 5 л ',
#        'Огнебиозащита ОГНЕБИО PROF 2 группа, бесцветный готовый состав / 65 л',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, бесцветный готовый состав / 30 л',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, красный готовый состав / 65 л',
#        'ОГНЕБИОЗАЩИТА  I группа, красный  готовый состав / 20 кг',
#        'Гель эконом-класса для мытья  посуды вручную. С ароматом яблока Cooky Apple E концентрированное средство / 5 л ПЭТ',
#        'Гель эконом-класса для мытья  посуды вручную. Без запаха Cooky Е концентрированное средство / 5 л ПЭТ',
#        'Гелеобразное средство с антибактериальным эффектом для мытья посуды вручную. Без запаха Cooky Plus концентрированное средство / 5 л ПЭТ',
#        'Гель для мытья  посуды вручную. Без запаха Cooky Apple с ароматом яблока концентрированное средство / 0,5 л ',
#        'Средство для мытья посуды в посудомоечной машине. Для жесткой воды Cooky Splash Soft концентрат 1:200-1:2000 / 10 л',
#        'Средство для мытья посуды в посудомоечной машине. Для жесткой воды Cooky Splash Hard концентрат 1:200-1:2000 / 10 л',
#        'Средство для чистки акриловых поверхностей Bath  Acryl концентрат 1:30-1:80 / 0,75 л',
#        'Пена для чистки ковров, мягкой мебели и текстиля Carpet Shampoo Активная пенаготовый состав / 0,4 л ',
#        'Концентрат для чистки и антимикробной обработки пищевого технологического оборудования Cooky Stuff концентрат 1:20-1:200 / 20 л',
#        'Концентрат для мытья полов и стен Multipower "Цитрус" концентрат / 0,8 л',
#        'Средство для удаления ржавчины и минеральных отложений щадящего действия Bath Acid  концентрат 1:200-1:500 / 0,75 л ',
#        'Универсальное моющее и чистящее средство Universal Spray+концентрат 1:20-1:100 / 5 л',
#        'Стиральный порошок для белых тканей Crystal White + / 5 кг ПЭТ',
#        'C тиральный порошок для цветных тканей с функцией "защита цвета" Crystal Color / 5 кг ПЭТ',
#        'Универсальное моющее средство эконом - класса Universal E концентрат 1:10-1:100 / 1 л',
#        'Герметик акриловый цвет тик, 3 кг.',
#        'Средство для комплексного мытья и отбеливания поверхностей с дезинфицирующим эффектом.Duty Belizna концентрат 1:200-1:3000 / 5 л ',
#        'Кондиционер для белья с ароматом "Альпийская свежесть"Crystal Rinser концентрат / 2 л ',
#        'Лак яхтный PROSEPT, полуматовыйготовый состав / 2 л',
#        'Шампунь-гель для душа 2 в 1 Ivee, 5 л',
#        'Лак яхтный PROSEPT, глянцевыйготовый состав / 2 л ',
#        'Лак яхтный PROSEPT, глянцевый,готовый состав / 0,9 л ',
#        'Антисептик  ECO EXTERIOR / 10 л',
#        'Средство для удаления гипсовой пыли Duty White концентрат 1:10-1:100 / 5 л  ',
#        'Антисептик ECO ULTRA, коричневый / 10 л',
#        'Удалитель плесени FUNGI CLEAN концентрат 1:1 / 5 л',
#        'Антисептик  ECO ULTRA, коричневый / 20 л',
#        'Удалитель мха концентрат 1:1 / 1 л ',
#        'Удалитель мха готовый состав / 5 л ',
#        'Удалитель плесени FUNGI CLEAN концентрат 1:1 / 1 л',
#        'Защита от плесени FUNGI STOP концентрат  1:10 / 1 л',
#        'Защитная пропитка от мхаконцентрат 1:10 / 5 л ',
#        'Шампунь-гель для душа 2 в 1 Alifee, 5 л',
#        'Набор для бани (Universal Wood, Multipower Wood)',
#        'Антисептик ECO ULTRA коричневый / 5 л',
#        'Отбеливатель для древесины PROSEPT ECO 50 готовый состав / 5 л',
#        'Лак яхтный PROSEPT, полуматовый,готовый состав / 0,9 л',
#        'Отбеливатель для древесины PROSEPT ECO 50 готовый состав / 10 л',
#        'Защита от плесени FUNGI STOP концентрат  1:10 / 5 л',
#        'Удалитель мха готовый состав / 1 л ',
#        'Отбеливатель для древесины PROSEPT ECO 50 готовый  состав / 1 кг',
#        'Удалитель плесени FUNGI CLEAN готовый состав / 0,5 л',
#        'Лак для камня PROSEPT готовый состав / 0,9 л',
#        'Набор для люстр Anti-Dust спрей, 0.5 л, 2 шт',
#        'Шампунь для чистки ковров и мягкой мебели Carpet Shampoo концентрат 1:20-1:120 / 1 л',
#        'Лак для бани и сауны PROSEPT готовый состав / 0,9 л ',
#        'Средство для чистки люстр Universal Anti-dust готовый состав / 0,5 л',
#        'Средство для удаления клейкой ленты, клея, наклеек Duty Universal готовый состав / 2 л',
#        'Набор для люстр Anti-Dust спрей, 0.5 л, 3 шт',
#        'Средство для удаления наклеек Duty Universal / 210 мл',
#        'Шампунь для сухой чистки ковров и текстильных изделий Carpet DryClean концентрат 1:20-1:100 / 0,5 л',
#        'Шампунь для сухой чистки ковров и текстильных изделий Carpet DryClean концентрат 1:20-1:100 / 1 л',
#        'Шампунь для чистки ковров и мягкой мебели Carpet Shampoo концентрат 1:20-1:120 / 5 л',
#        'Лак для камня PROSEPT готовый состав / 2 л',
#        'Лак для бани и сауны PROSEPT готовый состав / 2 л ',
#        'Герметик акриловый цвет орех, ф/п 600 мл (12 штук )',
#        'Герметик акриловый цвет медовый, 15 кг.',
#        'Герметик акриловый цвет орех, ф/п 600 мл',
#        'Герметик акриловый цвет сосна, 15 кг.',
#        'Герметик акриловый цвет орех, 15 кг.',
#        'Герметик акриловый  цвет сосна, ф/п 600 мл (12 штук )',
#        'Кондиционер для белья с ароматом Японского чая Crystal Rinser концентрат / 5 л ',
#        'Кондиционер для белья с ароматом  королевского Ириса Crystal Rinser концентрат / 5 л ',
#        'Кондиционер для белья с ароматом "Альпийская свежесть"Crystal Rinser концентрат / 5 л ',
#        'Герметик акриловый цвет медовый, ф/п 600 мл',
#        'Герметик акриловый  цвет белый , ф/п 600 мл. (12 штук )',
#        'Герметик акриловый цвет белый, 15 кг.',
#        'Кондиционер для белья с ароматом лепестков Сакуры Crystal Rinser концентрат / 5 л ',
#        'Кондиционер для белья без красителей и ароматизаторов Crystal Rinser концентрат / 5 л ',
#        'Кондиционер для белья с ароматом экзотических цветов Crystal Rinser концентрат / 5 л ',
#        'Кондиционер для белья с ароматом экзотических цветов Crystal Rinser концентрат / 2 л ',
#        'Набор Антисептик-грунт О SB BASE, 1 л, 2 шт',
#        'Антисептик-грунт OSB BASE готовый состав / 1 л',
#        'Кондиционер для белья с ароматом Японского чая Crystal Rinser концентрат / 2 л ',
#        'Набор Multipower Wood, 1 л, 2 шт',
#        'Антисептик-грунт OSB BASE готовый состав / 10 л',
#        'Набор Universal Wood спрей, 0.5 л, 2 шт',
#        'Средство для мытья плитки и керамогранита Multipower Kerama концентрат  / 5 л',
#        'Средство для мытья плитки и керамогранита Multipower Kerama концентрат  / 1 л',
#        'Моющее средство для бани и сауны Multipower Wood концентрат / 1 л',
#        'Спрей для очистки полков в банях и саунах Universal Wood готовый состав / 0,5 л',
#        'Кондиционер для белья без красителей и ароматизаторов Crystal Rinser концентрат / 2 л ',
#        'Удалитель ржавчины RUST REMOVER концентрат  1:2 / 5 л',
#        'Антисептик усиленный невымываемый PROSEPT ULTRA MAX концентрат 1:10 / 5 кг',
#        'Отбеливатель для древесины PROSEPT 50 концентрат 1:1 / 1 л',
#        'Антисептик усиленный невымываемый PROSEPT ULTRA MAX концентрат 1:10 / 1 кг',
#        'Антисептик универсальный для наружных и внутренних работ PROSEPT UNIVERSAL концентрат 1:10 / 1 л',
#        'Антисептик против грибка и плесени АНТИПЛЕСЕНЬ готовый состав / 10 л',
#        'Антисептик против грибка и плесени АНТИПЛЕСЕНЬ готовый состав / 5 л',
#        'Отбеливатель для древесины PROSEPT 50 концентрат 1:1 / 10 л',
#        'Отбеливатель для древесины PROSEPT 50 концентрат 1:1 / 20 л',
#        'Антисептик универсальный для наружных и внутренних работ PROSEPT UNIVERSAL концентрат 1:10 / 20 л',
#        'Антисептик универсальный для наружных и внутренних работ PROSEPT UNIVERSAL концентрат 1:10 / 5 л',
#        'Средство для ухода за мебелью (полироль)Universal Polish  готовый состав / 0,5 л ',
#        'Спрей для столешниц и раковин из искусственного камня и гранита Cooky Spray  готовый состав / 0,5 л',
#        'Моющий концентрат для удаления индустриальных загрязнений Duty General концентрат 1:10-1:80 / 5 л',
#        'Нейтрализатор неприятных запахов FLOX PROF готовый состав / 0,5 л ',
#        'Концентрат эконом-класса для мытья полов Multipower E (цитрус)  концентрат 1:5-1:150 / 5 л',
#        'Концентрат эконом-класса для мытья полов Multipower E (цитрус)  концентрат 1:5-1:150 / 1 л',
#        'Средство для удаления жировых загрязнений. Без растворителей Duty Care концентрат 1:4-1:65 / 5 л',
#        'Средство для снятия обоев спрей / 1 л',
#        'Концентрат эконом-класса для мытья полов Multipower E концентрат 1:5-1:150 / 5 л',
#        'Средство для мытья полов всех типов PROSEPT Multipower E, 1 л.',
#        'Нейтрализатор неприятных запахов FLOX PROF готовый состав / 5 л ',
#        'Универсальное средство на основе ЧАС с дезинфицирующим эффектом UN-DZ готовый состав / 0,5 л',
#        'Спрей для очистки каминных стекол от сажи и копоти Universal Hard 0,5 л',
#        'Спрей для очистки каминных стекол от сажи и копоти Universal Hard готовый состав / 0,5 л',
#        'Жидкое гель-мыло с перламутром. Без цвета, без запаха Diona готовый состав / 5 л ',
#        'Антибактериальное мыло Diona Antibac готовое средство / 0,5 л ',
#        'Нейтрализатор неприятных запахов Flox «Чарующий Стамбул» готовый состав / 0,4 л ',
#        'Антибактериальное мыло Diona Antibac готовое средство / 5 л ',
#        'Удалитель ржавчины RUST REMOVER готовый состав / 0,5 л',
#        'Нейтрализатор неприятных запахов Flox «Романтичный Прованс» готовый состав / 0,4 л ',
#        'Нейтрализатор запаха с ароматом морского бриза Flox Sea I  готовый состав / 0,5 л ',
#        'Универсальное средство на основе ЧАС с дезинфицирующим эффектом UN-DZ готовый состав / 5 л',
#        'Нейтрализатор неприятных запахов Flox «Солнечная Тоскана» готовый состав / 0,4 л ',
#        'Грунт по старой краске готовый состав / 2,5 кг',
#        'Универсальный пятновыводитель Candy готовый состав / 5 л ',
#        'Краска для плит OSB для внутренних и наружных работ Super Elastic / 7 кг',
#        'Очиститель эпоксидного налета Epoxy Cleaner готовый состав / 0,5 л ',
#        'Краска-грунт фасадная для плит OSB Proff 3 в 1 Liquid Rubber / 7 кг',
#        'Грунт БЕТОНКОНТАКТ готовый состав / 3 кг',
#        'Краска для плит OSB для внутренних и наружных работ Super Elastic / 14 кг',
#        'Грунт БЕТОНКОНТАКТ готовый состав / 1,3 кг',
#        'Универсальный пятновыводитель Candy готовый состав / 0,5 л ',
#        'Краска-грунт фасадная для плит OSB Proff 3 в 1 Liquid Rubber / 14 кг',
#        'Краска-грунт фасадная для плит OSB Proff 3 в 1 Liquid Rubber / 1 кг',
#        'Очиститель эпоксидного налета Epoxy Cleaner концентрат 1:2 / 1 л ',
#        'Шпатлевка-замазка для заделки глубоких выбоин и трещин Plastix / 5 кг',
#        'Шпатлевка-замазка для заделки глубоких выбоин и трещин Plastix / 1,4 кг',
#        'Шпатлевка для плит OSBProplast / 1,3 кг',
#        'Средство для мытья и восстановления полов с полимерным покрытием Multipower Polish концентрат 1:8-1:20 / 5 л',
#        'Полимерное покрытие для пола (сухой остаток 20%) Polish 250 готовый состав / 5 л ',
#        'Шпатлевка-замазка для заделки швов по монтажной пене Flastic / 1,4 кг',
#        'Шпатлевка-замазка для заделки швов по монтажной пене Flastic / 5 кг',
#        'Защитная пропитка от мхаконцентрат 1:10 / 1 л ',
#        'Средство для чистки гриля и духовых шкафов Cooky Grill Gel концентрированное средство 1:1 – 1:50 / 1 л',
#        'Полимерное покрытие для пола (сухой остаток 20%) Polish 200 готовый состав / 5 л ',
#        'Шпатлевка для плит OSBProplast / 7 кг',
#        'Краска для плит OSB для внутренних и наружных работ Super Elastic / 1 кг',
#        'Универсальный концентрат для санитарных комнат с антимикробным эффектом Bath Uni готовый состав / 0,5 л',
#        'Универсальный спрей для санитарных комнат Bath Spray готовый состав / 0,5 л',
#        'Очиститель для нержавеющей стали и цветных металлов Universal Clean готовый состав / 0,5 л',
#        'Средство для уборки и дезинфекции санитарных комнат Bath DZ Концентрат 1:8-1:100 / 1 л ',
#        'Средство для мытья стекол и зеркал Optic Crystal готовый состав / 0,5 л ',
#        'Средство для мытья стекол и зеркал с антистатическим эффектом      Optic Shine концентрат 1:50-1:100 / 0,5 л ',
#        'Средство для чистки акриловых поверхностей Bath  Acryl концентрат 1:30-1:80 / 1 л',
#        'Грунт АКВАИЗОЛ, голубой, концентрат  1:4 / 3 л',
#        'Средство для удаления ржавчины и минеральных отложений щадящего действия Bath Acid концентрат 1:200-1:500 / 1 л ',
#        'Средство усиленного действия для удаления ржавчины и минеральных отложений Bath Acid +  концентрат 1:200-1:500 / 1 л ',
#        'Средство для удаления плесени  с дезинфицирующим эффектом Bath Fungi концентрат 1:50-1:100 / 0,5 л',
#        'Гель для мытья  посуды вручную. Без запаха Cooky концентрированное средство / 1 л ',
#        'Гелеобразное средство усиленного действия для удаления ржавчины и минеральных отложений Bath Extra концентрат 1:10-1:100 / 5 л',
#        'Средство для чистки гриля и духовых шкафов Cooky Grill концентрированное средство / 0,55 л',
#        'Гелеобразное средство усиленного действия для удаления ржавчины и минеральных отложений Bath Extra концентрат 1:10-1:100 / 0,75 л',
#        'Гель для мытья  посуды вручную. Без запаха Cooky Fruit с ароматом фруктовконцентрированное средство / 1 л ',
#        'Средство для устранения засоров в трубах Bath Prof концентрат 1:100 / 1 л',
#        'Гель для мытья  посуды вручную. Без запаха Cooky концентрированное средство / 5 л ',
#        'Средство для мытья и отбеливания посуды с дезинфицирующим эффектом. Cooky White концентрат 1:50-1:100 / 5 л',
#        'Средство для мытья стекол и зеркал Optic C+концентрат 1:50-1:100 / 5 л ',
#        'Средство для мытья стекол и зеркал с антистатическим эффектом      Optic Shine концентрат 1:50-1:100 / 5 л ',
#        'Гель для мытья  посуды вручную. Без запаха Cooky Apple с ароматом яблока концентрированное средство / 1 л ',
#        'Средство для мытья полов всех типов Multipower Neutral концентрат 1:64 - 1:500 / 1 л',
#        'Средство для мытья стекол и зеркал Optic Crystal готовый состав / 5 л ',
#        'Антисептик невымываемый PROSEPT ECO ULTRA готовый состав / 20 л',
#        'Средство для мытья посуды в посудомоечной машине. Для жесткой воды Cooky Splash Soft концентрат 1:200-1:2000 / 5 л',
#        'Грунт АКВАИЗОЛ, розовый, концентрат  1:9 / 3 л',
#        'Грунт АКВАИЗОЛ, влагоизолирующий,готовый состав / 3 л',
#        'Усиленное чистящее средство с антистатическим эффектом Universal Spray Активная пенаготовый состав / 0,4 л',
#        'Гелеобразный концентрат для мытья посуды в посудомоечных машинах. Для воды любой степени жесткости Splash Lime концентрат / 1 л ',
#        'Универсальное моющее и чистящее средство Universal Spray готовый состав / 5 л',
#        'Средство для мытья посуды в посудомоечной машине. Для жесткой воды Cooky Splash Hard концентрат 1:200-1:2000 / 5 л',
#        'Антисептик невымываемый PROSEPT ECO ULTRA готовый состав / 10 л',
#        'Грунт АКВАИЗОЛ, розовый, концентрат  1:9 / 1 л',
#        'Жидкое моющее средство для стирки спортивной одежды, обуви и пуховиков Crystal Sport концентрат / 1 л ',
#        'Жидкий моющий концентрат для стирки белья  Crystal концентрат / 3 л ',
#        'Жидкое моющее средство для стирки белых и светлых тканей Crystal Black концентрат / 1 л ',
#        'Жидкое моющее средство для стирки белых и светлых тканей Crystal Black концентрат / 3 л ',
#        'Жидкое моющее средство для стирки спортивной одежды, обуви и пуховиков Crystal Sport концентрат / 3 л ',
#        'Средство усиленного действия для мытья всех типов полов Multipower Prof концентрат 1:20 -1:300 / 1 л ',
#        'Средство для мытья светлых полов с отбеливающим эффектом Multipower White концентрат 1:20-1:200 / 5 л',
#        'Средство усиленного действия для мытья всех типов полов Multipower Prof концентрат 1:20 -1:300 / 5 л ',
#        'Жидкий моющий концентрат для стирки белья  с ароматом алоэ вера Crystal концентрат / 3 л ',
#        'Грунт АКВАИЗОЛ, голубой, концентрат  1:4 / 1 л',
#        'Антисептик универсальный ХМФ-БФ, ГОСТ / 10 л',
#        'Антисептик трудновымываемый ХМББ, ГОСТ / 5 л',
#        'Антисептик для влажной древесины PROSEPT BiO концентрат 1:19  / 1 л',
#        'Антисептик трудновымываемый ХМББ, ГОСТ / 10 л',
#        'Антисептик  ECO UNIVERSAL  / 10 л',
#        'Жидкий моющий концентрат для стирки белья  с ароматом белых цветов Crystal концентрат / 3 л ',
#        'Антисептик для влажной древесины PROSEPT BiO концентрат 1:19 / 20 л',
#        'Антисептик  ECO UNIVERSAL / 5 л',
#        'Антисептик против жуков и других биопоражении АНТИЖУК / 10 л',
#        'Антисептик универсальный ХМФ-БФ, ГОСТ / 5 л',
#        'Жидкое моющее средство для стирки белых и светлых тканей Crystal White концентрат / 1 л ',
#        'Антисептик для влажной древесины PROSEPT BiO концентрат 1:19 / 5 л',
#        'Антисептик  ECO EXTERIOR / 5 л',
#        'Жидкое моющее средство для стирки белых и светлых тканей Crystal White концентрат / 3 л ',
#        'Краска резиновая серый Ral 7004 / 3 кг',
#        'Очиститель фасадов SALT CLEANER концентрат 1:2 / 5 л',
#        'Антисептик для внутренних работ ECO INTERIOR / 10 л',
#        'Сухой концентрат огнебиозащита мешок / 16 кг',
#        'Антисептик для внутренних работ ECO INTERIOR/ 5 л',
#        'Краска резиновая зеленый мох Ral 6005 / 3 кг',
#        'Средство для удаления граффити, маркера, краски Duty Graffiti готовый состав, аэрозоль / 0,4 л',
#        'Средство для мытья фасадов и дорожных покрытий Duty Hard +   концентрат / 1 л ',
#        'Средство для мытья полов всех типов Multipower Neutral концентрат 1:64 - 1:500 / 5 л',
#        'Средство для мытья фасадов и дорожных покрытий Duty Hard +   концентрат / 5 л',
#        'Средство для удаления граффити, маркера, краски Duty Graffiti готовый состав, аэрозоль / 2 л',
#        'Краска резиновая зеленый мох Ral 6005 / 1 кг',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, красный готовый состав / 5 л',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, красный готовый состав / 20 л',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, бесцветный готовый состав / 20 л',
#        'Огнебиозащита ОГНЕБИО PROF 2 группа, бесцветный готовый состав / 20 л',
#        'Антисептик для внутренних работ PROSEPT SAUNA концентрат 1:10 / 5 л',
#        'Краска резиновая серый Ral 7004 / 1 кг',
#        'Краска резиновая коричневый Ral 8017 / 1 кг',
#        'Краска резиновая белый Ral 9003 / 3 кг',
#        'Краска резиновая черный Ral 9004  / 1 кг',
#        'Краска резиновая черный Ral 9004  / 3 кг',
#        'Огнебиозащита ОГНЕБИО PROF 2 группа, красный готовый состав / 20 л',
#        'Средство для изделий из кожи, очистка и уход Duty Leather готовый состав, аэрозоль / 0,4 л ',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, бесцветный готовый состав / 10 л',
#        'Антисептик для внутренних работ PROSEPT INTERIOR концентрат 1:10 / 5 л',
#        'Антисептик многофункциональный ФБС, ГОСТ / 5 л',
#        'Масло для защиты полков в саунах и банях SAUNA OIL / 0,25 л',
#        'Антисептик невымываемый PROSEPT ULTRA коричневый концентрат 1:10 / 20 л',
#        'Антисептик для внутренних работ PROSEPT INTERIOR концентрат 1:10 / 1 л',
#        'Антисептик многофункциональный ФБС, ГОСТ / 10 л',
#        'Антисептик невымываемый PROSEPT ULTRA коричневый концентрат 1:10 / 5 л',
#        'Антисептик трудновымываемый для наружных работ PROSEPT EXTERIOR концентрат 1:19 / 20 л',
#        'Масло для защиты полков в саунах и банях PROSEPT SAUNA OIL готовый  состав  /  1 л',
#        'Антисептик трудновымываемый для наружных работ PROSEPT EXTERIOR концентрат 1:19 / 1 л',
#        'ОГНЕБИОЗАЩИТА  I группа, бесцветный готовый состав / 10 кг',
#        'ОГНЕБИОЗАЩИТА для древесины 2 группа, красный готовый  состав / 10 кг',
#        'Удалитель цемента CEMENT CLEANER концентрат 1:2 / 1 л',
#        'Антисептик для бани и сауны ECO SAUNA готовый состав / 5 л',
#        'PROSEPT огнебиозащита для древесины с цветовой индикацией. Высшая (1-ая) группа, 20 л.',
#        'Антисептик невымываемый PROSEPT ULTRA концентрат 1:10  / 5 л',
#        'Антисептик для бани и сауны ECO SAUNA готовый состав / 10 л',
#        'Антисептик невымываемый PROSEPT ULTRA концентрат 1:10 / 20 л',
#        'Антисептик невымываемый ХМ-11, ГОСТ / 5 л',
#        'Удалитель цемента CEMENT CLEANER концентрат 1:2 / 5 л',
#        'Антисептик невымываемый ХМ-11, ГОСТ / 10 л',
#        'ОГНЕБИОЗАЩИТА I группа, красный  готовый состав / 10 кг',
#        'ОГНЕБИОЗАЩИТА для древесины 2 группа, бесцветный  готовый состав / 10 кг',
#        'Универсальный концентрат для мытья полов Multipower FLOOR концентрат 1:10-1:200 / 1 л',
#        'Универсальный пенный обезжириватель для  пищевого  производства с антимикробным эффектом Duty Foam концентрат 1:20-1:100 / 5 л ',
#        'Концентрат для мытья полов MULTIPOWER с ароматом цитрусаконцентрат / 1 л',
#        'Средство для удаления напольных защитных покрытий Duty Stripper концентрат 1:20-1:50 / 5 л',
#        'Средство для обезжиривания поверхностей и удаления стойких запахов Duty Citrus концентрат 1:1-1:30 / 5 л',
#        'Средство для обезжиривания поверхностей и удаления стойких запахов Duty Citrus концентрат 1:1-1:30 / 1 л',
#        'ОГНЕБИОЗАЩИТА для древесины 2 группа, красный готовый состав / 20 кг',
#        'Универсальный концентрат для мытья полов Multipower FLOOR концентрат 1:10-1:200 / 5 л',
#        'Средство для уборки и дезинфекции санитарных комнат Bath DZ Концентрат 1:8-1:100 / 5 л ',
#        'Жидкое моющее средство для стирки цветных тканей Crystal Color концентрат / 3 л ',
#        'Усиленное средство для уборки после строительства Duty Extra Plus концентрат 1:2-1:120 / 5 л ',
#        'Герметик акриловый цвет Медовый, 15 кг',
#        'Краска резиновая коричневый Ral 8017 / 3 кг',
#        'Средство для чистки производственных помещений и оборудования с дезинфицирующим эффектом Duty Hard концентрат 1:2-1:60 / 1 л',
#        'Лак паркетный  PROSEPT, глянцевый,готовый состав / 0,9 л',
#        'Жидкое моющее средство для стирки шерсти, шелка и деликатных тканей Crystal Delicate концентрат / 3 л ',
#        'Универсальное моющее средство Universal Prof  концентрат 1:10 - 1:200 / 1 л',
#        'Средство для удаления ржавчины и минеральных отложений щадящего действия Bath Acid концентрат 1:200-1:500 / 5 л ',
#        'Средство для чистки производственных помещений и оборудования с дезинфицирующим эффектом Duty Hard концентрат 1:2-1:60 / 5 л',
#        'Лак интерьерный PROSEPT готовый состав / 0,9 л',
#        'Лак паркетный  PROSEPT, полуматовый,готовый состав / 0,9 л',
#        'Лак интерьерный PROSEPT готовый состав / 2 л',
#        'Пропитка для камня AQUAISOL концентрат  1:2 / 5 л',
#        'Хлорные таблетки с антибактериальным эффектом TAB-DZ / 1 кг',
#        'Средство усиленного действия для удаления ржавчины и минеральных отложений Bath Acid + концентрат 1:200-1:500 / 5 л ',
#        'Средство для уборки после строительства Duty Extra концентрат 1:2-1:100 / 1 л ',
#        'Средство для уборки после строительства Duty Extra концентрат 1:2-1:100 / 5 л ',
#        'Универсальное моющее средство Universal Prof  концентрат 1:10 - 1:200 / 5 л',
#        'Универсальное моющее средство с дезинфицирующим эффектом Universal DZ концентрат 1:10- 1:120 / 5 л',
#        'Универсальный концентрат для санитарных комнат с антимикробным эффектом Bath Uni готовый состав / 5 л',
#        'Средство для уборки и дезинфекции санитарных комнат Bath DZ Концентрат 1:8-1:100 / 0,75 л ',
#        'Средство для чистки акриловых поверхностей Bath  Acryl концентрат 1:30-1:80 / 5 л',
#        'Универсальное моющее средство с дезинфицирующим эффектом Universal DZ концентрат 1:10- 1:120 / 1 л',
#        'Средство для чистки коптильных камер Cooky Smoke концентрат 1:10-1:100 / 5 л',
#        'Грунт УКРЕПЛЯЮЩИЙготовый состав / 10 л',
#        'Грунт УКРЕПЛЯЮЩИЙготовый состав / 3 л',
#        'Чистящий крем для кухни Cooky Universal  "ледяная свежесть"готовый состав / 0,5 л ',
#        'Ополаскиватель для пароконвектоматов с режимом автомат. Очистки Splash Shine концентрат / 5 л',
#        'Специальная соль для посудомоечных машин Splash готовый состав / 1,5 кг',
#        'Средство для чистки гриля и духовых шкафов Cooky Grill Gel концентрированное средство 1:1 – 1:50 / 5 л',
#        'Средство для удаления плесени  с дезинфицирующим эффектом Bath Fungi концентрат 1:50-1:100 / 5 л',
#        'Ополаскиватель для посудомоечных машин всех типов Splash Rinser концентрат / 0,8 л ',
#        'Чистящий крем для кухни Cooky Universal с ароматом цитруса готовый состав / 0,5 л ',
#        'Концентрат для чистки и антимикробной обработки пищевого технологического оборудования Cooky Stuff концентрат 1:20-1:200 / 5 л',
#        'Средство для чистки гриля и духовых шкафов Cooky Grill концентрированное средство / 5 л',
#        'Грунт УНИВЕРСАЛЬНЫЙ, пропиточныйготовый состав / 3 л',
#        'Пропитка для камня  AQUAISOL концентрат  1:2 / 1 л',
#        'Удалитель ржавчины RUST REMOVER концентрат 1:2 / 1 л',
#        'Герметик акриловый цвет Медовый, 7 кг',
#        'Антисептик трудновымываемый для наружных работ PROSEPT EXTERIOR концентрат 1:19 / 5 л',
#        'Удалитель цемента CEMENT CLEANER готовый состав / 0,5 л',
#        'Защита от плесени FUNGI STOP готовый состав / 0,5 л',
#        'Средство для удаления клейкой ленты, клея, наклеек Duty Universal готовый состав / 400 мл',
#        'Огнебиозащита ОГНЕБИО PROF l, 1 группа, красный готовый состав / 10 л',
#        'Герметик акриловый цвет Орех, 7 кг',
#        'Антисептик невымываемый PROSEPT ECO ULTRA готовый состав / 5 л',
#        'Герметик акриловый цвет Сосна, 7 кг',
#        'Средство для устранения засоров в трубах Bath Prof концентрат 1:100 / 5 л',
#        'Гелеобразное средство усиленного действия для удаления ржавчины и минеральных отложений Bath Extra концентрат 1:10-1:100 / 1 л',
#        'Средство для снятия обоев  концентрат  1:19 / 0,5 л',
#        'Очиститель фасадов SALT CLEANER концентрат 1:2 / 1 л',
#        'Антисептик-грунт OSB BASE готовый состав / 5 л',
#        'Грунт АКВАИЗОЛ, влагоизолирующий,готовый состав / 10 л',
#        'Антисептик против жуков и других биопоражении АНТИЖУК / 5 л',
#        'Краска резиновая белый Ral 9003 / 1 кг',
#        'Грунт УНИВЕРСАЛЬНЫЙ, пропиточныйготовый состав / 10 л',
#        'Средство для удаления гипсовой пыли Duty White концентрат 1:10-1:100 / 1 л  ',
#        'Добавка против появления плесени / 0,25 л',
#        'Универсальное моющее и чистящее средство Universal Spray готовый состав / 0,5 л',
#        'Кислотный ополаскиватель для посудомоечных машин Splash Rinser концентрат 1:200-1:3000 / 5 л ',
#        'Жидкое моющее средство для стирки цветных тканей Crystal Color концентрат / 1 л ',
#        'Средство для уборки помещений после пожара с дезинфицирующим эффектом Duty Black концентрат 1:20-1:50 / 5 л',
#        'Жидкое моющее средство для стирки шерсти, шелка и деликатных тканей Crystal Delicate концентрат / 1 л ',
#        'Средство для чистки гриля и духовых шкафов Cooky Grill Gel концентрированное средство 1:1 – 1:50 / 0,5 л',
#        'Средство для мытья полов с полимерным покрытием Multipower Bright концентрат 1:65-1:500 / 5 л',
#        'Средство усиленного действия для удаления ржавчины и минеральных отложений Bath Acid +  концентрат 1:200-1:500 / 0,75 л '],
#       dtype=object)

# %% [markdown]
# Проблемы устранены.

# %% [markdown]
# Пропущеные категории можно восполнить по схожим товарам из этой же категории.

# %%
# Заполнение пропущенных значений в категориях на основе группировки по первым 3-4 словам в названиях товаров
data_products['category_id'].fillna(data_products['name'].apply(extract_keywords), inplace=True)

# %% [markdown]
# Для пропусков в ценах поставим просто заглушку -1.

# %%
data_products['cost'].fillna('-1', inplace=True)
data_products['recommended_price'].fillna('-1', inplace=True)

# %%
(data_products.isna().sum() / len(data_products)) *100
# Out:
# id                   0.0
# article              0.0
# name                 0.0
# cost                 0.0
# recommended_price    0.0
# category_id          0.0
# ozon_name            0.0
# name_1c              0.0
# wb_name              0.0
# volume               0.0
# units_of_meas        0.0
# concent              0.0
# units                0.0
# dtype: float64

# %%
data_key
# Out:
#         id        key  dealer_id  product_id
# 0        1     546227          2          12
# 1        2     651265          2         106
# 2        3     546257          2         200
# 3        4     546408          2          38
# 4        5     651258          2         403
# ...    ...        ...        ...         ...
# 1695  2019  530017190         18         267
# 1696  2020  530139882         18         286
# 1697  2021  534659036         18         129
# 1698  2022  898350801         18           1
# 1699  2023  534666258         18         128
#
# [1700 rows x 4 columns]

# %%
data_key.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1700 non-null   int64
#  1   key         1700 non-null   object
#  2   dealer_id   1700 non-null   int64
#  3   product_id  1700 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 53.3+ KB

# %%
# Список наименований товаров из таблицы data_products
product_names = data_products['name'].tolist()

# Предобработка наименований товаров
preprocessed_names = [preprocess_text(name) for name in product_names]

# Преобразование векторизации
vectorizer = TfidfVectorizer()
vectorized_names = vectorizer.fit_transform(preprocessed_names).toarray()

# Применение векторизации к таблице data_products
data_products['vectorized_name'] = list(vectorized_names)

# Применение векторизации к таблице data_dealers
data_dealers['vectorized_name'] = list(vectorizer.transform(data_dealers['product_name'].apply(preprocess_text)).toarray())

# %%
# Поиск топ 5 наиболее подходящих товаров для каждого товара из таблицы data_dealers
top_matches = []
for index, row in data_dealers.iterrows():
    query_vector = row['vectorized_name']
    similarity_scores = data_products['vectorized_name'].apply(lambda x: (x * query_vector).sum())
    top_matches_indices = similarity_scores.nlargest(5).index.tolist()
    top_matches.append(data_products.loc[top_matches_indices, 'name'].tolist())

# %%
# Создание нового датафрейма с результатами
results = pd.DataFrame({'product_name': data_dealers['product_name'], 'top_matches': top_matches})

# Преобразование столбца top_matches в отдельные столбцы
results_expanded = results['top_matches'].apply(pd.Series)

# Объединение результатов с исходным датафреймом
results = pd.concat([results['product_name'], results_expanded], axis=1)

# %%
results.sample(10)
# Out:
#                                             product_name  \
# 2324   Просепт Professional Duty Graffiti средство дл...
# 14385  Просепт Professional Duty White удалитель стро...
# 12845  Просепт Multipower Wood моющее средство для ба...
# 15540  Просепт Super Rubber краска резиновая (12 кг) ...
# 4538   Жидкое мыло Diona Antibac с антибактериальным ...
# 6621   Кондиционер для белья PROSEPT Crystal Rinser К...
# 8756   Просепт Professional Bath Acid Plus усиленное ...
# 15446  Просепт Bio Lasur антисептик лессирующий защит...
# 3797   Просепт 50 отбеливатель для древесины (1 л) же...
# 16133  Чистящее средство PROSEPT Bath Uni, с антимикр...
#
#                                                        0  \
# 2324   Средство для удаления граффити, маркера, краск...
# 14385  Средство для удаления гипсовой пыли Duty White...
# 12845  Моющее средство для бани и сауны Multipower Wo...
# 15540      Краска резиновая зеленый мох Ral 6005 / 12 кг
# 4538   Антибактериальное мыло Diona Antibac готовое с...
# 6621   Кондиционер для белья без красителей и аромати...
# 8756   Усиленное средство для уборки после строительс...
# 15446  Антисептик лессирующий BiO LASUR / бесцветный ...
# 3797   Отбеливатель для древесины PROSEPT 50 концентр...
# 16133  Универсальный концентрат для санитарных комнат...
#
#                                                        1  \
# 2324   Средство для удаления граффити, маркера, краск...
# 14385  Средство для удаления гипсовой пыли Duty White...
# 12845   Набор для бани (Universal Wood, Multipower Wood)
# 15540       Краска резиновая зеленый мох Ral 6005 / 3 кг
# 4538   Антибактериальное мыло Diona Antibac готовое с...
# 6621   Кондиционер для белья без красителей и аромати...
# 8756   Средство усиленного действия для удаления ржав...
# 15446  Антисептик лессирующий BiO LASUR / бесцветный ...
# 3797   Отбеливатель для древесины PROSEPT 50 концентр...
# 16133  Универсальный концентрат для санитарных комнат...
#
#                                                        2  \
# 2324   Средство для удаления граффити, маркера, краск...
# 14385                Удалитель мха концентрат 1:1 / 1 л
# 12845  Лак для бани и сауны PROSEPT готовый состав / ...
# 15540       Краска резиновая зеленый мох Ral 6005 / 1 кг
# 4538   Антибактериальное мыло Diona Antibac готовое с...
# 6621   Кондиционер для белья с ароматом "Альпийская с...
# 8756   Средство усиленного действия для удаления ржав...
# 15446  Антисептик лессирующий BiO LASUR / бесцветный ...
# 3797   Отбеливатель для древесины PROSEPT 50 концентр...
# 16133  Средство для удаления плесени  с дезинфицирующ...
#
#                                                        3  \
# 2324                    Набор DUTY GRAFFITI, 0.4 л, 2 шт
# 14385          Набор Удалитель мха, концентрат 1 л, 2 шт
# 12845  Лак для бани и сауны PROSEPT готовый состав / ...
# 15540            Краска резиновая белый Ral 9003 / 12 кг
# 4538   Жидкое мыло с антибактериальным компонентом дл...
# 6621   Кондиционер для белья с ароматом "Альпийская с...
# 8756   Средство усиленного действия для удаления ржав...
# 15446      Антисептик лессирующий BiO LASUR / орех / 9 л
# 3797   Отбеливатель для древесины PROSEPT 50 концентр...
# 16133  Средство для удаления плесени  с дезинфицирующ...
#
#                                                        4
# 2324   Средство для удаления наклеек Duty Universal /...
# 14385                Удалитель мха готовый состав / 5 л
# 12845  Антисептик для бани и сауны ECO SAUNA готовый ...
# 15540             Краска резиновая белый Ral 9003 / 3 кг
# 4538   Жидкое гель-мыло с перламутром. Без цвета, без...
# 6621   Кондиционер для белья с ароматом экзотических ...
# 8756   Средство для ухода за мебелью (полироль)Univer...
# 15446    Антисептик лессирующий BiO LASUR / орех / 0,9 л
# 3797   Отбеливатель для древесины PROSEPT 50 концентр...
# 16133  Усиленное чистящее средство с антистатическим ...
